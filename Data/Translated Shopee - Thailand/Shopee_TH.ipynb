# %%
#combine files 
import glob 
import os
#clean 
import string
import pandas as pd
import numpy as np
import emoji
import nltk
import re 
from cleantext import clean
#sleep timer 
import time 
import logging
import threading
#show most common words
from collections import Counter
#word cloud 
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from googletrans import Translator

# %%
files = os.path.join("/*.csv")
files = glob.glob(files)
df = pd.concat(map(pd.read_csv, files), ignore_index=True)
df.to_csv("combined_shopeeTH.csv")
df
# Out:
#                username                 date        variation  rating  \
# 0        sharpjakkaphan  2022-01-23 11:15:56        ขาว 5ชั้น     5.0
# 1          milkpummarin  2022-01-16 13:21:36        ขาว 5ชั้น     4.0
# 2       kamonwanyotchot  2021-12-16 14:39:15        ขาว 3ชั้น     5.0
# 3            oti346do0o  2021-09-05 19:25:25        ขาว 2ชั้น     4.0
# 4               c*****m  2021-10-13 12:47:18        เทา 3ชั้น     4.0
# ...                 ...                  ...              ...     ...
# 109560           _new_.  2021-11-14 15:02:10  DI06 (2K) Black     5.0
# 109561     eittipol1234  2021-11-17 22:34:59      DI22 FHD 2K     5.0
# 109562     weeraphong_k  2021-11-20 00:28:57  DI06 (2K) Black     5.0
# 109563     poloordinary  2021-10-24 02:48:59     DI01 (1080P)     5.0
# 109564      phaysahasit  2021-11-14 20:17:34  DI06 (2K) Black     5.0
#
#                                                   comment
# 0       คุ้มค่ามาก วางในซอกที่แคบได้พอดี วางของได้เยอะ...
# 1       สั่ง30ติดปีใหม่แต่ก้ส่งเร็วยุ ได้วันที่4.  แต่...
# 2       สินค้าจัดส่งนานไปหน่อยค่ะ ยังไม่ได้ลองประกอบสิ...
# 3       ส่งไวค่ะ ขนส่งโทรแจ้งก่อน แต่แพคไม่ดีเลย กล่อง...
# 4       การจัดส่งโอเค แต่กล่องมีรอยขาด2ที่ สินค้าไม่ได...
# ...                                                   ...
# 109560                                                NaN
# 109561                                                NaN
# 109562                                                NaN
# 109563                                                NaN
# 109564                                                NaN
#
# [109565 rows x 5 columns]

# %%
df = df.dropna()

# %%
df
# Out:
#                   username                 date     variation  rating  \
# 0           sharpjakkaphan  2022-01-23 11:15:56     ขาว 5ชั้น     5.0
# 1             milkpummarin  2022-01-16 13:21:36     ขาว 5ชั้น     4.0
# 2          kamonwanyotchot  2021-12-16 14:39:15     ขาว 3ชั้น     5.0
# 3               oti346do0o  2021-09-05 19:25:25     ขาว 2ชั้น     4.0
# 4                  c*****m  2021-10-13 12:47:18     เทา 3ชั้น     4.0
# ...                    ...                  ...           ...     ...
# 108653       fondue.studio  2021-05-10 01:17:58  DI01 (1080P)     5.0
# 108654          iam.chalat  2021-07-12 15:26:44     DI06 (2K)     5.0
# 108655  ronnachaisnimaanta  2021-06-22 12:15:47     DI06 (2K)     5.0
# 108656        bunchaph5548  2021-07-16 10:58:27     DI06 (2K)     1.0
# 108657  ningpanyavisedpong  2021-08-27 18:46:40     DI06 (2K)     4.0
#
#                                                   comment
# 0       คุ้มค่ามาก วางในซอกที่แคบได้พอดี วางของได้เยอะ...
# 1       สั่ง30ติดปีใหม่แต่ก้ส่งเร็วยุ ได้วันที่4.  แต่...
# 2       สินค้าจัดส่งนานไปหน่อยค่ะ ยังไม่ได้ลองประกอบสิ...
# 3       ส่งไวค่ะ ขนส่งโทรแจ้งก่อน แต่แพคไม่ดีเลย กล่อง...
# 4       การจัดส่งโอเค แต่กล่องมีรอยขาด2ที่ สินค้าไม่ได...
# ...                                                   ...
# 108653            กล้องชัดดีค่ะ ใช้งานง่าย เหมาะสมกับราคา
# 108654                                          ส่งไวม๊าก
# 108655                                   ส่งเร็วมากครับ👍👍
# 108656              ผิดนัดการส่งของ ไม่มีความเป็นมืออาชีพ
# 108657  กล้องชัดดี แต่ปรับยาก ตรงที่ปรับเหมือนมีแต่ให้...
#
# [57920 rows x 5 columns]

# %%
df["translated text"] = df["comment"]
# Out:
# /var/folders/5w/0kxl7gbj5vqb93sccvkxwrzc0000gn/T/ipykernel_50403/183252566.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["translated text"] = df["comment"]

# %%
#initialize the Translator
translator = Translator()
source_lan = "th" 
translated_to= "en"

# %%
counter = 57874
for index, row in df[57874:].iterrows():  
    try:
        df['translated text'][index] = translator.translate(str(row['comment']), src=source_lan, dest = translated_to).text
        print(df['translated text'][index])
        counter += 1
        print(counter)
    except Exception as e:
        time.sleep(15)
        continue
# Out:
# /var/folders/5w/0kxl7gbj5vqb93sccvkxwrzc0000gn/T/ipykernel_50403/2017387040.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['translated text'][index] = translator.translate(str(row['comment']), src=source_lan, dest = translated_to).text
# Good product
# 57875
# Well, worth it.
# 57876
# Clear picture
# 57877
# Received the product
# 57878
# The picture is very clear.
# 57879
# The camera is clearly sent.
# 57880
# Good quality products, cheaper than others, of course, good quality products, cheaper than others, of course, good quality products, cheaper than others, of course.Good quality, cheaper than others, of course, good quality products, cheaper than others, of course, good quality products, cheaper than others, of course, good quality products.Cheaper
# 57881
# The full picture is very good.
# 57882
# Good product. Send a lot. Suitable for the price.
# 57883
# Very clear.
# 57884
# The camera has a little footprint but normal use.
# 57885
# Products work wellThe transport is well wrapped as well.
# 57886
# Get the correct delivery as ordered
# 57887
# Extremely
# 57888
# The camera is obviously installed and easy to use.
# 57889
# The Product Is Quite Oh, Shipping is A But Slow
# 57890
# Not clear, not worth it.
# 57891
# The camera is clear, easy to use, easy to carry.
# 57892
# Looks good, good package, but haven't tried it yet.
# 57893
# Wait for the delivery
# 57894
# Good quality delivery products
# 57895
# Send sensitive products to order
# 57896
# good
# 57897
# GGGGHHHJJJJ
# 57898
# Very good if the collapse is guaranteed.
# 57899
# Good product qualitySend the goods very quickly
# 57900
# Good quality products satisfied
# 57901
# A little clearness
# 57902
# Very clear, more clear than you think.
# 57903
# Safe
# 57904
# After the sale is very good
# 57905
# Very clear picture
# 57906
# The image is clear.
# 57907
# Clear picture, small camera
# 57908
# good
# 57909
# One day to very good quality
# 57910
# Good quality products, Widei delivery 👏🏻
# 57911
# Can not be used at all
# 57912
# good
# 57913
# The camera comes in good condition.Delivery is fast
# 57914
# Quality products, OK, send sensitive, recommend it.
# 57915
# The camera is clear, easy to use, suitable for the price.
# 57916
# Send Wai
# 57917
# Very fast delivery 👍👍
# 57918
# Default deliveryNo professional
# 57919
# The camera is clearly good, but the adjustment is difficult to adjust.The screen is not a good camera. But fine, straight, adjusted like having to competeThe screen is not a good camera. But fine, straight, adjusted like having to competeThe screen is not a good camera. But fine, straight, adjusted like having to competeThe screen is not
# 57920

# %%
# df.to_csv('df1.csv')#save first just incase
df = pd.read_csv('df1.csv')

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')


def clean_text_round1(text):
    '''Make text lowercase, remove punctuation, remove words containing numbers and lemmatize/stem.'''
    text = str(text).lower()
    text = re.sub('#\w*', '', text)
    text = re.sub('@\w*', '', text)    
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = clean(text, no_emoji=True)
    text = ' '.join([word for word in text.split() if word not in (stop)])
    return text

# Let's take a look at the updated text
df['Reviews'] = pd.DataFrame(df['translated text'].apply(clean_text_round1))
df
# Out:
#        Unnamed: 0            username                 date     variation  \
# 0               0      sharpjakkaphan  2022-01-23 11:15:56     ขาว 5ชั้น
# 1               1        milkpummarin  2022-01-16 13:21:36     ขาว 5ชั้น
# 2               2     kamonwanyotchot  2021-12-16 14:39:15     ขาว 3ชั้น
# 3               3          oti346do0o  2021-09-05 19:25:25     ขาว 2ชั้น
# 4               4             c*****m  2021-10-13 12:47:18     เทา 3ชั้น
# ...           ...                 ...                  ...           ...
# 57915      108653       fondue.studio  2021-05-10 01:17:58  DI01 (1080P)
# 57916      108654          iam.chalat  2021-07-12 15:26:44     DI06 (2K)
# 57917      108655  ronnachaisnimaanta  2021-06-22 12:15:47     DI06 (2K)
# 57918      108656        bunchaph5548  2021-07-16 10:58:27     DI06 (2K)
# 57919      108657  ningpanyavisedpong  2021-08-27 18:46:40     DI06 (2K)
#
#        rating                                            comment  \
# 0         5.0  คุ้มค่ามาก วางในซอกที่แคบได้พอดี วางของได้เยอะ...
# 1         4.0  สั่ง30ติดปีใหม่แต่ก้ส่งเร็วยุ ได้วันที่4.  แต่...
# 2         5.0  สินค้าจัดส่งนานไปหน่อยค่ะ ยังไม่ได้ลองประกอบสิ...
# 3         4.0  ส่งไวค่ะ ขนส่งโทรแจ้งก่อน แต่แพคไม่ดีเลย กล่อง...
# 4         4.0  การจัดส่งโอเค แต่กล่องมีรอยขาด2ที่ สินค้าไม่ได...
# ...       ...                                                ...
# 57915     5.0            กล้องชัดดีค่ะ ใช้งานง่าย เหมาะสมกับราคา
# 57916     5.0                                          ส่งไวม๊าก
# 57917     5.0                                   ส่งเร็วมากครับ👍👍
# 57918     1.0              ผิดนัดการส่งของ ไม่มีความเป็นมืออาชีพ
# 57919     4.0  กล้องชัดดี แต่ปรับยาก ตรงที่ปรับเหมือนมีแต่ให้...
#
#                                          translated text  \
# 0      Very worthwhile, put in a narrow niche.Paste m...
# 1      Order 30 on the new year, but I can send the f...
# 2      The product is delivered for a long time.Have ...
# 3      Send sensitive, transport, call firstBut the p...
# 4      Delivery okBut the box has 2 deficiencyThe pro...
# ...                                                  ...
# 57915  The camera is clear, easy to use, suitable for...
# 57916                                           Send Wai
# 57917                              Very fast delivery 👍👍
# 57918                    Default deliveryNo professional
# 57919  The camera is clearly good, but the adjustment...
#
#                                                  Reviews
# 0      worthwhile put narrow nichepaste morelooks str...
# 1      order new year send faster day black stain wra...
# 2      product delivered long timehave yet tried asse...
# 3      send sensitive transport call firstbut pack go...
# 4      delivery okbut box deficiencythe product bubbl...
# ...                                                  ...
# 57915               camera clear easy use suitable price
# 57916                                           send wai
# 57917                                      fast delivery
# 57918                    default deliveryno professional
# 57919  camera clearly good adjustment difficult adjus...
#
# [57920 rows x 8 columns]

# %%
def remove_url(removed_url):
    removed_url = removed_url.lower()
    removed_url = re.sub('[%s]' % re.escape(string.punctuation), '', removed_url)
    removed_url = re.sub('\w*\d\w*', '', removed_url)
    return removed_url
df['Reviews'] = pd.DataFrame(df['Reviews'].apply(remove_url))

df
# Out:
#        Unnamed: 0            username                 date     variation  \
# 0               0      sharpjakkaphan  2022-01-23 11:15:56     ขาว 5ชั้น
# 1               1        milkpummarin  2022-01-16 13:21:36     ขาว 5ชั้น
# 2               2     kamonwanyotchot  2021-12-16 14:39:15     ขาว 3ชั้น
# 3               3          oti346do0o  2021-09-05 19:25:25     ขาว 2ชั้น
# 4               4             c*****m  2021-10-13 12:47:18     เทา 3ชั้น
# ...           ...                 ...                  ...           ...
# 57915      108653       fondue.studio  2021-05-10 01:17:58  DI01 (1080P)
# 57916      108654          iam.chalat  2021-07-12 15:26:44     DI06 (2K)
# 57917      108655  ronnachaisnimaanta  2021-06-22 12:15:47     DI06 (2K)
# 57918      108656        bunchaph5548  2021-07-16 10:58:27     DI06 (2K)
# 57919      108657  ningpanyavisedpong  2021-08-27 18:46:40     DI06 (2K)
#
#        rating                                            comment  \
# 0         5.0  คุ้มค่ามาก วางในซอกที่แคบได้พอดี วางของได้เยอะ...
# 1         4.0  สั่ง30ติดปีใหม่แต่ก้ส่งเร็วยุ ได้วันที่4.  แต่...
# 2         5.0  สินค้าจัดส่งนานไปหน่อยค่ะ ยังไม่ได้ลองประกอบสิ...
# 3         4.0  ส่งไวค่ะ ขนส่งโทรแจ้งก่อน แต่แพคไม่ดีเลย กล่อง...
# 4         4.0  การจัดส่งโอเค แต่กล่องมีรอยขาด2ที่ สินค้าไม่ได...
# ...       ...                                                ...
# 57915     5.0            กล้องชัดดีค่ะ ใช้งานง่าย เหมาะสมกับราคา
# 57916     5.0                                          ส่งไวม๊าก
# 57917     5.0                                   ส่งเร็วมากครับ👍👍
# 57918     1.0              ผิดนัดการส่งของ ไม่มีความเป็นมืออาชีพ
# 57919     4.0  กล้องชัดดี แต่ปรับยาก ตรงที่ปรับเหมือนมีแต่ให้...
#
#                                          translated text  \
# 0      Very worthwhile, put in a narrow niche.Paste m...
# 1      Order 30 on the new year, but I can send the f...
# 2      The product is delivered for a long time.Have ...
# 3      Send sensitive, transport, call firstBut the p...
# 4      Delivery okBut the box has 2 deficiencyThe pro...
# ...                                                  ...
# 57915  The camera is clear, easy to use, suitable for...
# 57916                                           Send Wai
# 57917                              Very fast delivery 👍👍
# 57918                    Default deliveryNo professional
# 57919  The camera is clearly good, but the adjustment...
#
#                                                  Reviews
# 0      worthwhile put narrow nichepaste morelooks str...
# 1      order new year send faster day black stain wra...
# 2      product delivered long timehave yet tried asse...
# 3      send sensitive transport call firstbut pack go...
# 4      delivery okbut box deficiencythe product bubbl...
# ...                                                  ...
# 57915               camera clear easy use suitable price
# 57916                                           send wai
# 57917                                      fast delivery
# 57918                    default deliveryno professional
# 57919  camera clearly good adjustment difficult adjus...
#
# [57920 rows x 8 columns]

# %%
df['Reviews'] = df['Reviews'].str.replace('\n',' ')
df
# Out:
#        Unnamed: 0            username                 date     variation  \
# 0               0      sharpjakkaphan  2022-01-23 11:15:56     ขาว 5ชั้น
# 1               1        milkpummarin  2022-01-16 13:21:36     ขาว 5ชั้น
# 2               2     kamonwanyotchot  2021-12-16 14:39:15     ขาว 3ชั้น
# 3               3          oti346do0o  2021-09-05 19:25:25     ขาว 2ชั้น
# 4               4             c*****m  2021-10-13 12:47:18     เทา 3ชั้น
# ...           ...                 ...                  ...           ...
# 57915      108653       fondue.studio  2021-05-10 01:17:58  DI01 (1080P)
# 57916      108654          iam.chalat  2021-07-12 15:26:44     DI06 (2K)
# 57917      108655  ronnachaisnimaanta  2021-06-22 12:15:47     DI06 (2K)
# 57918      108656        bunchaph5548  2021-07-16 10:58:27     DI06 (2K)
# 57919      108657  ningpanyavisedpong  2021-08-27 18:46:40     DI06 (2K)
#
#        rating                                            comment  \
# 0         5.0  คุ้มค่ามาก วางในซอกที่แคบได้พอดี วางของได้เยอะ...
# 1         4.0  สั่ง30ติดปีใหม่แต่ก้ส่งเร็วยุ ได้วันที่4.  แต่...
# 2         5.0  สินค้าจัดส่งนานไปหน่อยค่ะ ยังไม่ได้ลองประกอบสิ...
# 3         4.0  ส่งไวค่ะ ขนส่งโทรแจ้งก่อน แต่แพคไม่ดีเลย กล่อง...
# 4         4.0  การจัดส่งโอเค แต่กล่องมีรอยขาด2ที่ สินค้าไม่ได...
# ...       ...                                                ...
# 57915     5.0            กล้องชัดดีค่ะ ใช้งานง่าย เหมาะสมกับราคา
# 57916     5.0                                          ส่งไวม๊าก
# 57917     5.0                                   ส่งเร็วมากครับ👍👍
# 57918     1.0              ผิดนัดการส่งของ ไม่มีความเป็นมืออาชีพ
# 57919     4.0  กล้องชัดดี แต่ปรับยาก ตรงที่ปรับเหมือนมีแต่ให้...
#
#                                          translated text  \
# 0      Very worthwhile, put in a narrow niche.Paste m...
# 1      Order 30 on the new year, but I can send the f...
# 2      The product is delivered for a long time.Have ...
# 3      Send sensitive, transport, call firstBut the p...
# 4      Delivery okBut the box has 2 deficiencyThe pro...
# ...                                                  ...
# 57915  The camera is clear, easy to use, suitable for...
# 57916                                           Send Wai
# 57917                              Very fast delivery 👍👍
# 57918                    Default deliveryNo professional
# 57919  The camera is clearly good, but the adjustment...
#
#                                                  Reviews
# 0      worthwhile put narrow nichepaste morelooks str...
# 1      order new year send faster day black stain wra...
# 2      product delivered long timehave yet tried asse...
# 3      send sensitive transport call firstbut pack go...
# 4      delivery okbut box deficiencythe product bubbl...
# ...                                                  ...
# 57915               camera clear easy use suitable price
# 57916                                           send wai
# 57917                                      fast delivery
# 57918                    default deliveryno professional
# 57919  camera clearly good adjustment difficult adjus...
#
# [57920 rows x 8 columns]

# %%
column_titles = ['date','rating','Reviews']
df1 = df.reindex(columns=column_titles)
df1
# Out:
#                       date  rating  \
# 0      2022-01-23 11:15:56     5.0
# 1      2022-01-16 13:21:36     4.0
# 2      2021-12-16 14:39:15     5.0
# 3      2021-09-05 19:25:25     4.0
# 4      2021-10-13 12:47:18     4.0
# ...                    ...     ...
# 57915  2021-05-10 01:17:58     5.0
# 57916  2021-07-12 15:26:44     5.0
# 57917  2021-06-22 12:15:47     5.0
# 57918  2021-07-16 10:58:27     1.0
# 57919  2021-08-27 18:46:40     4.0
#
#                                                  Reviews
# 0      worthwhile put narrow nichepaste morelooks str...
# 1      order new year send faster day black stain wra...
# 2      product delivered long timehave yet tried asse...
# 3      send sensitive transport call firstbut pack go...
# 4      delivery okbut box deficiencythe product bubbl...
# ...                                                  ...
# 57915               camera clear easy use suitable price
# 57916                                           send wai
# 57917                                      fast delivery
# 57918                    default deliveryno professional
# 57919  camera clearly good adjustment difficult adjus...
#
# [57920 rows x 3 columns]

# %%
df1['year'] = df1['date'].str.split(' ').str[0].str.split('-').str[0]
df1['month'] = df1['date'].str.split(' ').str[0].str.split('-').str[1]
df1.drop(['date'], axis =1)
# Out:
#        rating                                            Reviews  year month
# 0         5.0  worthwhile put narrow nichepaste morelooks str...  2022    01
# 1         4.0  order new year send faster day black stain wra...  2022    01
# 2         5.0  product delivered long timehave yet tried asse...  2021    12
# 3         4.0  send sensitive transport call firstbut pack go...  2021    09
# 4         4.0  delivery okbut box deficiencythe product bubbl...  2021    10
# ...       ...                                                ...   ...   ...
# 57915     5.0               camera clear easy use suitable price  2021    05
# 57916     5.0                                           send wai  2021    07
# 57917     5.0                                      fast delivery  2021    06
# 57918     1.0                    default deliveryno professional  2021    07
# 57919     4.0  camera clearly good adjustment difficult adjus...  2021    08
#
# [57920 rows x 4 columns]

# %%
df_month = df1.groupby(by=['month']).count()
df_month
#to see which month have the most num of reveiws about SLOW delivery
# Out:
#        date  rating  Reviews  year
# month
# 01     5917    5917     5917  5917
# 02     6674    6674     6674  6674
# 03     7716    7716     7716  7716
# 04     1932    1932     1932  1932
# 05     2614    2614     2614  2614
# 06     2990    2990     2990  2990
# 07     3571    3571     3571  3571
# 08     4780    4780     4780  4780
# 09     5844    5844     5844  5844
# 10     5442    5442     5442  5442
# 11     5045    5045     5045  5045
# 12     5395    5395     5395  5395

# %%
#sentiment analysis 
from nltk.stem import WordNetLemmatizer 
lemmatizer = WordNetLemmatizer()
def clean_text_round2(text):
    word_list = nltk.word_tokenize(text)
    lemmatized_output = ' '.join([lemmatizer.lemmatize(w) for w in word_list])
    return lemmatized_output
df1['Review_lemma'] = pd.DataFrame(df1['Reviews'].apply(clean_text_round2))

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

def sentiment_scores(sentence):
    sid_obj = SentimentIntensityAnalyzer() 
    sentiment_dict = sid_obj.polarity_scores(sentence) 
    if sentiment_dict['compound'] >= 0.05 : 
       return "Positive"
    elif sentiment_dict['compound'] <= - 0.05 : 
        return "Negative"
    else : 
       return "Neutral"
        
df1['Sentiment score'] = pd.DataFrame(df1['Review_lemma'].apply(sentiment_scores))

# %%
column_titles = ['year','month','rating','Reviews','Sentiment score']
df1 = df1.reindex(columns=column_titles)
df1
# Out:
#        year month  rating                                            Reviews  \
# 0      2022    01     5.0  worthwhile put narrow nichepaste morelooks str...
# 1      2022    01     4.0  order new year send faster day black stain wra...
# 2      2021    12     5.0  product delivered long timehave yet tried asse...
# 3      2021    09     4.0  send sensitive transport call firstbut pack go...
# 4      2021    10     4.0  delivery okbut box deficiencythe product bubbl...
# ...     ...   ...     ...                                                ...
# 57915  2021    05     5.0               camera clear easy use suitable price
# 57916  2021    07     5.0                                           send wai
# 57917  2021    06     5.0                                      fast delivery
# 57918  2021    07     1.0                    default deliveryno professional
# 57919  2021    08     4.0  camera clearly good adjustment difficult adjus...
#
#       Sentiment score
# 0            Positive
# 1            Positive
# 2             Neutral
# 3            Positive
# 4            Negative
# ...               ...
# 57915        Positive
# 57916         Neutral
# 57917         Neutral
# 57918         Neutral
# 57919        Positive
#
# [57920 rows x 5 columns]

# %%
df1.to_csv('shopee_th_results.csv')

# %%
df_neg = df1.drop(df1[df1['Sentiment score'] != 'Negative'].index)
df_neg
# Out:
#        year month  rating                                            Reviews  \
# 4      2021    10     4.0  delivery okbut box deficiencythe product bubbl...
# 13     2021    10     4.0             well lets deduct wheel point difficult
# 38     2021    10     5.0  send quality price together difficult may stro...
# 39     2021    09     4.0  choose wrong delivery thatso goesthe second ro...
# 83     2021    11     5.0  come cheap priceand send fastfast shocked orde...
# ...     ...   ...     ...                                                ...
# 57653  2021    07     5.0            sent fast like angry cameintroduce shop
# 57700  2021    08     5.0                                              tired
# 57835  2021    07     4.0                             broken star box inside
# 57858  2021    05     5.0                           wfh used meeting problem
# 57898  2021    06     5.0                           good collapse guaranteed
#
#       Sentiment score
# 4            Negative
# 13           Negative
# 38           Negative
# 39           Negative
# 83           Negative
# ...               ...
# 57653        Negative
# 57700        Negative
# 57835        Negative
# 57858        Negative
# 57898        Negative
#
# [3261 rows x 5 columns]

# %%
cloud_string = df_neg['Reviews'].str.cat(sep=' ')

# %%
words = []
for word in cloud_string.split():
        words.append(word)
Counter(words).most_common()
# Out:
# [('product', 1777),
#  ('fast', 683),
#  ('shop', 679),
#  ('damaged', 652),
#  ('delivery', 631),
#  ('good', 611),
#  ('received', 566),
#  ('price', 484),
#  ('order', 413),
#  ('broken', 412),
#  ('use', 390),
#  ('send', 376),
#  ('damage', 364),
#  ('box', 353),
#  ('products', 352),
#  ('problem', 337),
#  ('quality', 321),
#  ('pack', 295),
#  ('time', 273),
#  ('well', 273),
#  ('little', 251),
#  ('used', 248),
#  ('ordered', 243),
#  ('sensitive', 228),
#  ('cheap', 215),
#  ('bad', 211),
#  ('lot', 197),
#  ('buy', 195),
#  ('difficult', 190),
#  ('long', 188),
#  ('try', 187),
#  ('color', 185),
#  ('first', 180),
#  ('dont', 180),
#  ('get', 176),
#  ('like', 169),
#  ('star', 165),
#  ('transport', 163),
#  ('complete', 159),
#  ('day', 158),
#  ('sent', 158),
#  ('soft', 158),
#  ('according', 154),
#  ('wrong', 153),
#  ('delivered', 152),
#  ('disappointed', 148),
#  ('quite', 145),
#  ('days', 137),
#  ('know', 135),
#  ('much', 133),
#  ('wrapped', 132),
#  ('new', 132),
#  ('considered', 128),
#  ('transportation', 125),
#  ('machine', 125),
#  ('ok', 124),
#  ('slow', 122),
#  ('one', 121),
#  ('wait', 120),
#  ('still', 119),
#  ('confused', 117),
#  ('must', 115),
#  ('service', 113),
#  ('ngong', 109),
#  ('okay', 108),
#  ('put', 108),
#  ('bag', 107),
#  ('eat', 105),
#  ('item', 104),
#  ('many', 102),
#  ('suitable', 102),
#  ('cover', 101),
#  ('come', 100),
#  ('quickly', 93),
#  ('exactly', 92),
#  ('inside', 91),
#  ('overall', 90),
#  ('size', 89),
#  ('waste', 88),
#  ('enough', 87),
#  ('find', 87),
#  ('worth', 85),
#  ('without', 84),
#  ('tried', 84),
#  ('hot', 84),
#  ('see', 83),
#  ('problems', 83),
#  ('hard', 82),
#  ('wheel', 81),
#  ('another', 81),
#  ('sound', 81),
#  ('normal', 79),
#  ('think', 79),
#  ('mm', 79),
#  ('bit', 78),
#  ('wrap', 76),
#  ('shocked', 75),
#  ('back', 75),
#  ('yet', 74),
#  ('condition', 73),
#  ('package', 72),
#  ('may', 71),
#  ('baht', 71),
#  ('thick', 70),
#  ('smell', 70),
#  ('doesnt', 69),
#  ('slowly', 69),
#  ('people', 68),
#  ('suck', 68),
#  ('shipping', 66),
#  ('bubble', 65),
#  ('secretly', 65),
#  ('blame', 65),
#  ('small', 65),
#  ('protein', 64),
#  ('productthe', 62),
#  ('really', 61),
#  ('want', 61),
#  ('big', 61),
#  ('take', 61),
#  ('correct', 61),
#  ('weight', 60),
#  ('completely', 59),
#  ('fastthe', 58),
#  ('waiting', 58),
#  ('taste', 58),
#  ('stars', 57),
#  ('havent', 57),
#  ('pain', 57),
#  ('plastic', 56),
#  ('cheaper', 56),
#  ('white', 56),
#  ('receive', 56),
#  ('straight', 55),
#  ('flash', 54),
#  ('short', 54),
#  ('go', 53),
#  ('check', 53),
#  ('answer', 53),
#  ('sending', 52),
#  ('normally', 52),
#  ('expensive', 52),
#  ('delay', 51),
#  ('store', 51),
#  ('using', 51),
#  ('real', 51),
#  ('deliverythe', 50),
#  ('work', 50),
#  ('picture', 50),
#  ('inexpensive', 49),
#  ('full', 49),
#  ('press', 49),
#  ('review', 49),
#  ('company', 49),
#  ('drops', 49),
#  ('call', 48),
#  ('light', 48),
#  ('gray', 47),
#  ('round', 47),
#  ('water', 47),
#  ('nose', 47),
#  ('already', 46),
#  ('would', 46),
#  ('return', 46),
#  ('staff', 46),
#  ('house', 46),
#  ('tell', 46),
#  ('terrible', 46),
#  ('black', 45),
#  ('items', 45),
#  ('delayed', 45),
#  ('never', 45),
#  ('every', 44),
#  ('look', 44),
#  ('regret', 44),
#  ('things', 43),
#  ('accurate', 43),
#  ('fire', 43),
#  ('image', 42),
#  ('eating', 42),
#  ('rod', 41),
#  ('cant', 41),
#  ('tight', 41),
#  ('shock', 41),
#  ('brand', 41),
#  ('sucking', 41),
#  ('swap', 41),
#  ('deg', 41),
#  ('pay', 40),
#  ('sheep', 40),
#  ('say', 40),
#  ('takes', 40),
#  ('pan', 40),
#  ('paper', 39),
#  ('ask', 39),
#  ('reduce', 39),
#  ('easy', 38),
#  ('change', 38),
#  ('nothing', 38),
#  ('inches', 38),
#  ('sleep', 38),
#  ('didnt', 37),
#  ('comes', 37),
#  ('alone', 37),
#  ('goods', 37),
#  ('lose', 37),
#  ('wrapping', 37),
#  ('came', 37),
#  ('contact', 37),
#  ('next', 37),
#  ('device', 36),
#  ('sensitivity', 36),
#  ('us', 36),
#  ('customer', 36),
#  ('thin', 36),
#  ('buying', 35),
#  ('chat', 34),
#  ('open', 34),
#  ('system', 34),
#  ('cancel', 34),
#  ('model', 34),
#  ('pink', 34),
#  ('anything', 33),
#  ('bought', 33),
#  ('hair', 33),
#  ('plus', 32),
#  ('customers', 32),
#  ('subsidize', 32),
#  ('also', 32),
#  ('orderedthe', 32),
#  ('old', 32),
#  ('loud', 32),
#  ('fully', 31),
#  ('money', 31),
#  ('soon', 31),
#  ('number', 31),
#  ('yesterday', 31),
#  ('boxes', 31),
#  ('deliver', 31),
#  ('sale', 31),
#  ('stores', 31),
#  ('collapse', 31),
#  ('isolate', 31),
#  ('power', 31),
#  ('give', 30),
#  ('goodthe', 30),
#  ('goodbut', 30),
#  ('need', 30),
#  ('air', 30),
#  ('alcohol', 30),
#  ('fragrance', 30),
#  ('guisology', 30),
#  ('thai', 30),
#  ('floor', 29),
#  ('cut', 29),
#  ('everything', 29),
#  ('code', 29),
#  ('today', 29),
#  ('parcel', 29),
#  ('large', 29),
#  ('compared', 29),
#  ('around', 29),
#  ('two', 29),
#  ('silent', 29),
#  ('heavy', 28),
#  ('stick', 28),
#  ('side', 28),
#  ('less', 28),
#  ('date', 28),
#  ('ill', 28),
#  ('soy', 28),
#  ('green', 28),
#  ('choose', 27),
#  ('make', 27),
#  ('strong', 27),
#  ('looks', 27),
#  ('material', 27),
#  ('person', 27),
#  ('stuck', 27),
#  ('piece', 27),
#  ('deliverybut', 27),
#  ('purchase', 27),
#  ('receiving', 27),
#  ('app', 27),
#  ('standard', 27),
#  ('point', 26),
#  ('read', 26),
#  ('carpet', 26),
#  ('right', 26),
#  ('shockproof', 26),
#  ('thought', 26),
#  ('thing', 26),
#  ('cushion', 26),
#  ('poor', 26),
#  ('fragrant', 26),
#  ('please', 26),
#  ('guarantee', 26),
#  ('together', 25),
#  ('actually', 25),
#  ('understand', 25),
#  ('cannot', 25),
#  ('affordable', 25),
#  ('low', 25),
#  ('worthwhile', 25),
#  ('x', 25),
#  ('line', 25),
#  ('installation', 25),
#  ('precision', 25),
#  ('value', 24),
#  ('available', 24),
#  ('lock', 24),
#  ('lost', 24),
#  ('trade', 24),
#  ('add', 24),
#  ('clip', 24),
#  ('body', 24),
#  ('fabric', 24),
#  ('whey', 24),
#  ('pass', 24),
#  ('effect', 24),
#  ('meet', 23),
#  ('help', 23),
#  ('afraid', 23),
#  ('pot', 23),
#  ('match', 23),
#  ('hurry', 23),
#  ('productsthe', 23),
#  ('sucked', 23),
#  ('almost', 23),
#  ('feel', 23),
#  ('bh', 23),
#  ('dust', 23),
#  ('lets', 22),
#  ('including', 22),
#  ('packing', 22),
#  ('wholesale', 22),
#  ('packed', 22),
#  ('cute', 22),
#  ('answered', 22),
#  ('fee', 22),
#  ('said', 22),
#  ('productgood', 22),
#  ('examination', 22),
#  ('omorons', 22),
#  ('mouse', 22),
#  ('camera', 22),
#  ('deduct', 21),
#  ('affect', 21),
#  ('lazy', 21),
#  ('room', 21),
#  ('discount', 21),
#  ('pieces', 21),
#  ('informed', 21),
#  ('home', 21),
#  ('vacuum', 21),
#  ('wellthe', 21),
#  ('boson', 21),
#  ('second', 20),
#  ('request', 20),
#  ('hurt', 20),
#  ('anyone', 20),
#  ('lack', 20),
#  ('pricethe', 20),
#  ('outside', 20),
#  ('thank', 20),
#  ('fear', 20),
#  ('edge', 20),
#  ('better', 20),
#  ('rounds', 20),
#  ('productsbut', 20),
#  ('blue', 20),
#  ('probably', 20),
#  ('seller', 20),
#  ('serious', 19),
#  ('set', 19),
#  ('layer', 19),
#  ('told', 19),
#  ('fastgood', 19),
#  ('way', 19),
#  ('place', 19),
#  ('plug', 19),
#  ('unfortunately', 19),
#  ('puzzled', 19),
#  ('even', 19),
#  ('claim', 19),
#  ('different', 19),
#  ('end', 19),
#  ('year', 19),
#  ('kerry', 19),
#  ('connect', 19),
#  ('dumbbell', 19),
#  ('beautiful', 18),
#  ('orderthe', 18),
#  ('capacity', 18),
#  ('ordering', 18),
#  ('bags', 18),
#  ('times', 18),
#  ('stop', 18),
#  ('whole', 18),
#  ('sitting', 18),
#  ('eaten', 18),
#  ('fan', 18),
#  ('shopthe', 17),
#  ('rarely', 17),
#  ('due', 17),
#  ('blamed', 17),
#  ('per', 17),
#  ('disadvantage', 17),
#  ('slightly', 17),
#  ('shopee', 17),
#  ('relatively', 17),
#  ('form', 17),
#  ('deliverygood', 17),
#  ('computer', 17),
#  ('pro', 17),
#  ('admin', 17),
#  ('high', 17),
#  ('envelope', 17),
#  ('suction', 17),
#  ('compact', 17),
#  ('deep', 17),
#  ('forget', 16),
#  ('goodthere', 16),
#  ('productvery', 16),
#  ('original', 16),
#  ('saw', 16),
#  ('refund', 16),
#  ('sorry', 16),
#  ('recommended', 16),
#  ('vv', 16),
#  ('productbut', 16),
#  ('quiet', 16),
#  ('inner', 16),
#  ('bottle', 16),
#  ('head', 16),
#  ('packaging', 16),
#  ('reed', 16),
#  ('sleeping', 16),
#  ('mattress', 16),
#  ('boxbut', 16),
#  ('priority', 16),
#  ('pak', 16),
#  ('deepblue', 16),
#  ('able', 15),
#  ('parts', 15),
#  ('responsible', 15),
#  ('found', 15),
#  ('looking', 15),
#  ('speed', 15),
#  ('thinking', 15),
#  ('leave', 15),
#  ('faster', 15),
#  ('longer', 15),
#  ('changed', 15),
#  ('pressed', 15),
#  ('bed', 15),
#  ('felt', 15),
#  ('red', 15),
#  ('services', 15),
#  ('battery', 15),
#  ('wearing', 14),
#  ('fastbut', 14),
#  ('express', 14),
#  ('attached', 14),
#  ('period', 14),
#  ('specified', 14),
#  ('follow', 14),
#  ('shipped', 14),
#  ('done', 14),
#  ('transported', 14),
#  ('since', 14),
#  ('works', 14),
#  ('made', 14),
#  ('receivedthe', 14),
#  ('three', 14),
#  ('v', 14),
#  ('shy', 14),
#  ('cold', 14),
#  ('flawed', 14),
#  ('feeling', 14),
#  ('inform', 14),
#  ('goodno', 14),
#  ('health', 14),
#  ('case', 14),
#  ('milk', 14),
#  ('fat', 14),
#  ('bluetooth', 14),
#  ('online', 14),
#  ('click', 14),
#  ('tired', 13),
#  ('widei', 13),
#  ('im', 13),
#  ('loose', 13),
#  ('phone', 13),
#  ('bigger', 13),
#  ('reduced', 13),
#  ('gang', 13),
#  ('start', 13),
#  ('caused', 13),
#  ('details', 13),
#  ('lucky', 13),
#  ('solve', 13),
#  ('lightweight', 13),
#  ('amount', 13),
#  ('cloth', 13),
#  ('j', 13),
#  ('completed', 13),
#  ('packthe', 13),
#  ('morning', 13),
#  ('btu', 13),
#  ('conditioner', 13),
#  ('version', 13),
#  ('heat', 13),
#  ('sit', 13),
#  ('wellbut', 13),
#  ('sun', 13),
#  ('others', 13),
#  ('cat', 13),
#  ('subsidized', 13),
#  ('expected', 13),
#  ('soi', 13),
#  ('cable', 13),
#  ('charcoal', 13),
#  ('enemy', 13),
#  ('sharp', 12),
#  ('pressure', 12),
#  ('shopgood', 12),
#  ('trying', 12),
#  ('permanent', 12),
#  ('top', 12),
#  ('okthe', 12),
#  ('sends', 12),
#  ('damagedthe', 12),
#  ('got', 12),
#  ('week', 12),
#  ('placed', 12),
#  ('subsidy', 12),
#  ('cell', 12),
#  ('accept', 12),
#  ('deduction', 12),
#  ('mother', 12),
#  ('trial', 12),
#  ('level', 12),
#  ('seen', 12),
#  ('productsgood', 12),
#  ('thousands', 12),
#  ('chance', 12),
#  ('careful', 12),
#  ('mouth', 12),
#  ('free', 12),
#  ('front', 12),
#  ('handle', 12),
#  ('install', 12),
#  ('noise', 12),
#  ('aftersales', 12),
#  ('chair', 12),
#  ('equal', 12),
#  ('mild', 12),
#  ('weak', 12),
#  ('exhibit', 12),
#  ('fake', 12),
#  ('clear', 12),
#  ('convenient', 12),
#  ('melt', 12),
#  ('immediately', 12),
#  ('rest', 12),
#  ('addition', 12),
#  ('guidus', 12),
#  ('frame', 12),
#  ('species', 12),
#  ('seagate', 12),
#  ('print', 12),
#  ('successfullythe', 11),
#  ('sure', 11),
#  ('force', 11),
#  ('story', 11),
#  ('transportationbut', 11),
#  ('torn', 11),
#  ('recommend', 11),
#  ('productfast', 11),
#  ('reasonable', 11),
#  ('opening', 11),
#  ('instead', 11),
#  ('let', 11),
#  ('wide', 11),
#  ('shockproofbut', 11),
#  ('matter', 11),
#  ('night', 11),
#  ('directly', 11),
#  ('allergic', 11),
#  ('butt', 11),
#  ('defective', 11),
#  ('returned', 11),
#  ('correctly', 11),
#  ('though', 11),
#  ('view', 11),
#  ('button', 11),
#  ('total', 11),
#  ('seat', 11),
#  ('fu', 11),
#  ('damagedbut', 11),
#  ('productsthere', 11),
#  ('bitter', 11),
#  ('worried', 11),
#  ('timethe', 11),
#  ('thickness', 11),
#  ('cleaner', 11),
#  ('sales', 11),
#  ('non', 11),
#  ('sticker', 11),
#  ('triedbut', 11),
#  ('screen', 11),
#  ('swope', 11),
#  ('usb', 11),
#  ('wheels', 10),
#  ('causing', 10),
#  ('difficultthe', 10),
#  ('subsidies', 10),
#  ('course', 10),
#  ('damagethe', 10),
#  ('assembly', 10),
#  ('distorted', 10),
#  ('type', 10),
#  ('going', 10),
#  ('personally', 10),
#  ('enter', 10),
#  ('crack', 10),
#  ('itemthe', 10),
#  ('fit', 10),
#  ('muchthe', 10),
#  ('transportationthe', 10),
#  ('conclusion', 10),
#  ('direct', 10),
#  ('leaves', 10),
#  ('label', 10),
#  ('pots', 10),
#  ('orderedgood', 10),
#  ('packno', 10),
#  ('break', 10),
#  ('love', 10),
#  ('sensitivegood', 10),
#  ('shocks', 10),
#  ('requesting', 10),
#  ('bagbut', 10),
#  ('four', 10),
#  ('technician', 10),
#  ('external', 10),
#  ('video', 10),
#  ('took', 10),
#  ('warranty', 10),
#  ('dhl', 10),
#  ('support', 10),
#  ('fiber', 10),
#  ('maybe', 10),
#  ('making', 10),
#  ('soonthe', 10),
#  ('prepare', 10),
#  ('ps', 10),
#  ('enoughthe', 10),
#  ('calling', 10),
#  ('sheets', 10),
#  ('refused', 10),
#  ('measure', 10),
#  ('half', 10),
#  ('increase', 10),
#  ('grams', 10),
#  ('episode', 10),
#  ('lb', 10),
#  ('within', 10),
#  ('single', 10),
#  ('keep', 10),
#  ('live', 10),
#  ('talk', 10),
#  ('mobile', 10),
#  ('asked', 10),
#  ('attention', 10),
#  ('dark', 10),
#  ('response', 10),
#  ('sim', 10),
#  ('internet', 10),
#  ('disk', 10),
#  ('okbut', 9),
#  ('thats', 9),
#  ('hole', 9),
#  ('corner', 9),
#  ('score', 9),
#  ('connection', 9),
#  ('name', 9),
#  ('shoot', 9),
#  ('opportunity', 9),
#  ('bottom', 9),
#  ('easily', 9),
#  ('frequently', 9),
#  ('satisfied', 9),
#  ('colors', 9),
#  ('durable', 9),
#  ('drawer', 9),
#  ('shockproofthe', 9),
#  ('fortunately', 9),
#  ('page', 9),
#  ('lacking', 9),
#  ('purchased', 9),
#  ('points', 9),
#  ('shockbut', 9),
#  ('fall', 9),
#  ('wasting', 9),
#  ('important', 9),
#  ('inch', 9),
#  ('boxthe', 9),
#  ('general', 9),
#  ('tape', 9),
#  ('sooner', 9),
#  ('thousand', 9),
#  ('installed', 9),
#  ('leak', 9),
#  ('cool', 9),
#  ('hours', 9),
#  ('cutting', 9),
#  ('mall', 9),
#  ('working', 9),
#  ('tv', 9),
#  ('later', 9),
#  ('orders', 9),
#  ('five', 9),
#  ('consider', 9),
#  ('spray', 9),
#  ('perfume', 9),
#  ('poured', 9),
#  ('strange', 9),
#  ('transfer', 9),
#  ('close', 9),
#  ('feet', 9),
#  ('sheet', 9),
#  ('something', 9),
#  ('decided', 9),
#  ('battle', 9),
#  ('badly', 9),
#  ('itbut', 9),
#  ('weighing', 9),
#  ('eyes', 9),
#  ('accordance', 9),
#  ('sounds', 9),
#  ('charging', 9),
#  ('preorder', 9),
#  ('fearing', 9),
#  ('stopped', 9),
#  ('minutes', 9),
#  ('pressing', 9),
#  ('printer', 9),
#  ('strongbut', 8),
#  ('went', 8),
#  ('guide', 8),
#  ('deliverythere', 8),
#  ('smaller', 8),
#  ('marks', 8),
#  ('address', 8),
#  ('notify', 8),
#  ('wasted', 8),
#  ('covered', 8),
#  ('pricebut', 8),
#  ('cushioning', 8),
#  ('likely', 8),
#  ('sensitivethe', 8),
#  ('middle', 8),
#  ('cheapest', 8),
#  ('class', 8),
#  ('risk', 8),
#  ('ten', 8),
#  ('exhausted', 8),
#  ('question', 8),
#  ('bang', 8),
#  ('impressed', 8),
#  ('gradually', 8),
#  ('information', 8),
#  ('flat', 8),
#  ('sick', 8),
#  ('broke', 8),
#  ('remove', 8),
#  ('fill', 8),
#  ('deliveryfast', 8),
#  ('freight', 8),
#  ('prevent', 8),
#  ('play', 8),
#  ('cost', 8),
#  ('shocking', 8),
#  ('range', 8),
#  ('tsu', 8),
#  ('running', 8),
#  ('card', 8),
#  ('productsno', 8),
#  ('months', 8),
#  ('knowing', 8),
#  ('cleaned', 8),
#  ('stand', 8),
#  ('yellow', 8),
#  ('aroma', 8),
#  ('food', 8),
#  ('lid', 8),
#  ('genuine', 8),
#  ('missing', 8),
#  ('possible', 8),
#  ('far', 8),
#  ('reviews', 8),
#  ('test', 8),
#  ('center', 8),
#  ('weaker', 8),
#  ('crab', 8),
#  ('toothe', 8),
#  ('wrinkled', 8),
#  ('flavor', 8),
#  ('closed', 8),
#  ('turn', 8),
#  ('shaking', 8),
#  ('design', 8),
#  ('sucks', 8),
#  ('episodes', 8),
#  ('insurance', 8),
#  ('advice', 8),
#  ('plugging', 8),
#  ('watch', 8),
#  ('data', 8),
#  ('throw', 8),
#  ('scales', 8),
#  ('daily', 8),
#  ('clearly', 8),
#  ('brokenthe', 8),
#  ('kg', 8),
#  ('atk', 8),
#  ('slim', 8),
#  ('hour', 8),
#  ('charge', 8),
#  ('van', 8),
#  ('program', 8),
#  ('nonshaking', 8),
#  ('drop', 7),
#  ('wear', 7),
#  ('stuff', 7),
#  ('push', 7),
#  ('kovad', 7),
#  ('slippery', 7),
#  ('layers', 7),
#  ('move', 7),
#  ('packthere', 7),
#  ('wrappingbut', 7),
#  ('disappointing', 7),
#  ('productsif', 7),
#  ('cm', 7),
#  ('bubblebut', 7),
#  ('saturday', 7),
#  ('wellno', 7),
#  ('respond', 7),
#  ('ground', 7),
#  ('arrived', 7),
#  ('drive', 7),
#  ('throughout', 7),
#  ('coin', 7),
#  ('grade', 7),
#  ('kept', 7),
#  ('provides', 7),
#  ('makes', 7),
#  ('shopnot', 7),
#  ('job', 7),
#  ('ml', 7),
#  ('reduction', 7),
#  ('transporting', 7),
#  ('diver', 7),
#  ('promotion', 7),
#  ('conditions', 7),
#  ('spin', 7),
#  ('packs', 7),
#  ('orderedfast', 7),
#  ('brands', 7),
#  ('years', 7),
#  ('responsibility', 7),
#  ('last', 7),
#  ('motor', 7),
#  ('evening', 7),
#  ('synthetic', 7),
#  ('slip', 7),
#  ('uses', 7),
#  ('liter', 7),
#  ('cause', 7),
#  ('fragrancethe', 7),
#  ('purple', 7),
#  ('style', 7),
#  ('face', 7),
#  ('polite', 7),
#  ('fix', 7),
#  ('topper', 7),
#  ('artificial', 7),
#  ('sewing', 7),
#  ('yes', 7),
#  ('rate', 7),
#  ('noon', 7),
#  ('past', 7),
#  ('sack', 7),
#  ('shipment', 7),
#  ('mixed', 7),
#  ('powder', 7),
#  ('regular', 7),
#  ('muscle', 7),
#  ('women', 7),
#  ('rash', 7),
#  ('administrator', 7),
#  ('wind', 7),
#  ('storage', 7),
#  ('afternoon', 7),
#  ('responded', 7),
#  ('message', 7),
#  ('scale', 7),
#  ('needed', 7),
#  ('pick', 7),
#  ('gold', 7),
#  ('smooth', 7),
#  ('previous', 7),
#  ('charged', 7),
#  ('guisusology', 7),
#  ('enems', 7),
#  ('wood', 7),
#  ('reply', 7),
#  ('touch', 7),
#  ('pork', 7),
#  ('orderbut', 7),
#  ('wifi', 7),
#  ('goodsuitable', 7),
#  ('ninja', 7),
#  ('princess', 7),
#  ('clean', 6),
#  ('timebut', 6),
#  ('medium', 6),
#  ('legs', 6),
#  ('key', 6),
#  ('responds', 6),
#  ('often', 6),
#  ('spare', 6),
#  ('rotation', 6),
#  ('additional', 6),
#  ('stiff', 6),
#  ('rating', 6),
#  ('productsnot', 6),
#  ('postpone', 6),
#  ('feels', 6),
#  ('daysthe', 6),
#  ('scroll', 6),
#  ('given', 6),
#  ('wants', 6),
#  ('hesitant', 6),
#  ('u', 6),
#  ('turned', 6),
#  ('pulling', 6),
#  ('gets', 6),
#  ('acquired', 6),
#  ('monday', 6),
#  ('storesthe', 6),
#  ('productthere', 6),
#  ('boxthere', 6),
#  ('fairly', 6),
#  ('goodnothing', 6),
#  ('disappear', 6),
#  ('fine', 6),
#  ('disappointment', 6),
#  ('ready', 6),
#  ('says', 6),
#  ('disappeared', 6),
#  ('reasonably', 6),
#  ('fastthere', 6),
#  ('lower', 6),
#  ('worse', 6),
#  ('productnot', 6),
#  ('visit', 6),
#  ('plant', 6),
#  ('loss', 6),
#  ('transportationdelayed', 6),
#  ('julydont', 6),
#  ('wellthere', 6),
#  ('similar', 6),
#  ('market', 6),
#  ('shopfast', 6),
#  ('ship', 6),
#  ('saying', 6),
#  ('e', 6),
#  ('pricecan', 6),
#  ('goodvery', 6),
#  ('pricethere', 6),
#  ('impressive', 6),
#  ('continue', 6),
#  ('left', 6),
#  ('country', 6),
#  ('stitching', 6),
#  ('called', 6),
#  ('lacks', 6),
#  ('secondary', 6),
#  ('fasttry', 6),
#  ('leaked', 6),
#  ('softbut', 6),
#  ('six', 6),
#  ('added', 6),
#  ('dumb', 6),
#  ('stinking', 6),
#  ('sold', 6),
#  ...]

# %%
add_stop_words = ['...' , 'package', 'even', 'use','call','one','though', 'didnt', 'dont', 'hasnt', 'c',]
stop_words = add_stop_words + stop 
#wordcloud for top 100 words 
wc = WordCloud(stopwords=stop_words, background_color="white", colormap="Dark2",
               max_font_size=150, random_state=42, max_words = 100)

wordcloud = wc.generate(cloud_string)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
plt.figure( figsize=(20,10) )
plt.imshow(wordcloud)

# %%
late_words = ['slow', 'late', 'long']
df_late = df_neg[df_neg['Reviews'].str.contains('|'.join(late_words))]
df_late = df_late.rename(columns ={'Reviews':'Late reviews'})

# %%
column_titles = ['rating','Reviews','Sentiment']
df_late = df_late.reindex(columns=column_titles)
df_late
# Out:
#        rating  Reviews  Sentiment
# 116       5.0      NaN        NaN
# 535       5.0      NaN        NaN
# 656       1.0      NaN        NaN
# 690       5.0      NaN        NaN
# 762       4.0      NaN        NaN
# ...       ...      ...        ...
# 56586     5.0      NaN        NaN
# 56659     2.0      NaN        NaN
# 56798     5.0      NaN        NaN
# 57326     2.0      NaN        NaN
# 57506     4.0      NaN        NaN
#
# [431 rows x 3 columns]

# %%
df_late.to_csv('Late_reviews_shopeeTH.csv')
