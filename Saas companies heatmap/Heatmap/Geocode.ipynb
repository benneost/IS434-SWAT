# %%
"""
Python script for batch geocoding of addresses using the Google Geocoding API.
This script allows for massive lists of addresses to be geocoded for free by pausing when the 
geocoder hits the free rate limit set by Google (2500 per day).  If you have an API key for paid
geocoding from Google, set it in the API key section.
Addresses for geocoding can be specified in a list of strings "addresses". In this script, addresses
come from a csv file with a column "Address". Adjust the code to your own requirements as needed.
After every 500 successul geocode operations, a temporary file with results is recorded in case of 
script failure / loss of connection later.
Addresses and data are held in memory, so this script may need to be adjusted to process files line
by line if you are processing millions of entries.
Shane Lynn
5th November 2016
"""

import pandas as pd
import requests
import logging
import time

logger = logging.getLogger("root")
logger.setLevel(logging.DEBUG)
# create console handler
ch = logging.StreamHandler()
ch.setLevel(logging.DEBUG)
logger.addHandler(ch)

#------------------ CONFIGURATION -------------------------------

# Set your Google API key here. 
# Even if using the free 2500 queries a day, its worth getting an API key since the rate limit is 50 / second.
# With API_KEY = None, you will run into a 2 second delay every 10 requests or so.
# With a "Google Maps Geocoding API" key from https://console.developers.google.com/apis/, 
# the daily limit will be 2500, but at a much faster rate.
# Example: API_KEY = 'AIzaSyC9azed9tLdjpZNjg2_kVePWvMIBq154eA'
# API_KEY = ''
# Backoff time sets how many minutes to wait between google pings when your API limit is hit
BACKOFF_TIME = 30
# Set your output file name here.
output_filename = 'companiesgeocode.csv'
# Set your input file here
input_filename = "CompaniesLocation.csv"
# Specify the column name in your input data that contains addresses here
address_column_name = "Address"
# Return Full Google Results? If True, full JSON results from Google are included in output
RETURN_FULL_RESULTS = False

#------------------ DATA LOADING --------------------------------

# Read the data to a Pandas Dataframe
data = pd.read_csv(input_filename, encoding='utf8')

if address_column_name not in data.columns:
	raise ValueError("Missing Address column in input data")

# Form a list of addresses for geocoding:
# Make a big list of all of the addresses to be processed.
addresses = data[address_column_name].tolist()

# **** DEMO DATA / IRELAND SPECIFIC! ****
# We know that these addresses are in Ireland, and there's a column for county, so add this for accuracy. 
# (remove this line / alter for your own dataset)
# addresses = (data[address_column_name] + ',' + data['County'] + ',Ireland').tolist()


#------------------	FUNCTION DEFINITIONS ------------------------

def get_google_results(address, api_key=None, return_full_response=False):
    """
    Get geocode results from Google Maps Geocoding API.
    
    Note, that in the case of multiple google geocode reuslts, this function returns details of the FIRST result.
    
    @param address: String address as accurate as possible. For Example "18 Grafton Street, Dublin, Ireland"
    @param api_key: String API key if present from google. 
                    If supplied, requests will use your allowance from the Google API. If not, you
                    will be limited to the free usage of 2500 requests per day.
    @param return_full_response: Boolean to indicate if you'd like to return the full response from google. This
                    is useful if you'd like additional location details for storage or parsing later.
    """
    # Set up your Geocoding url
    geocode_url = "https://maps.googleapis.com/maps/api/geocode/json?address={}".format(address)
    if api_key is not None:
        geocode_url = geocode_url + "&key={}".format(api_key)
        
    # Ping google for the reuslts:
    results = requests.get(geocode_url)
    # Results will be in JSON format - convert to dict using requests functionality
    results = results.json()
    
    # if there's no results or an error, return empty results.
    if len(results['results']) == 0:
        output = {
            "formatted_address" : None,
            "latitude": None,
            "longitude": None,
            "accuracy": None,
            "google_place_id": None,
            "type": None,
            "postcode": None
        }
    else:    
        answer = results['results'][0]
        output = {
            "formatted_address" : answer.get('formatted_address'),
            "latitude": answer.get('geometry').get('location').get('lat'),
            "longitude": answer.get('geometry').get('location').get('lng'),
            "accuracy": answer.get('geometry').get('location_type'),
            "google_place_id": answer.get("place_id"),
            "type": ",".join(answer.get('types')),
            "postcode": ",".join([x['long_name'] for x in answer.get('address_components') 
                                  if 'postal_code' in x.get('types')])
        }
        
    # Append some other details:    
    output['input_string'] = address
    output['number_of_results'] = len(results['results'])
    output['status'] = results.get('status')
    if return_full_response is True:
        output['response'] = results
    
    return output

#------------------ PROCESSING LOOP -----------------------------

# Ensure, before we start, that the API key is ok/valid, and internet access is ok
test_result = get_google_results("London, England", API_KEY, RETURN_FULL_RESULTS)
if (test_result['status'] != 'OK') or (test_result['formatted_address'] != 'London, UK'):
    logger.warning("There was an error when testing the Google Geocoder.")
    raise ConnectionError('Problem with test results from Google Geocode - check your API key and internet connection.')

# Create a list to hold results
results = []
# Go through each address in turn
for address in addresses:
    # While the address geocoding is not finished:
    geocoded = False
    while geocoded is not True:
        # Geocode the address with google
        try:
            geocode_result = get_google_results(address, API_KEY, return_full_response=RETURN_FULL_RESULTS)
        except Exception as e:
            logger.exception(e)
            logger.error("Major error with {}".format(address))
            logger.error("Skipping!")
            geocoded = True
            
        # If we're over the API limit, backoff for a while and try again later.
        if geocode_result['status'] == 'OVER_QUERY_LIMIT':
            logger.info("Hit Query Limit! Backing off for a bit.")
            time.sleep(BACKOFF_TIME * 60) # sleep for 30 minutes
            geocoded = False
        else:
            # If we're ok with API use, save the results
            # Note that the results might be empty / non-ok - log this
            if geocode_result['status'] != 'OK':
                logger.warning("Error geocoding {}: {}".format(address, geocode_result['status']))
            logger.debug("Geocoded: {}: {}".format(address, geocode_result['status']))
            results.append(geocode_result)           
            geocoded = True

    # Print status every 100 addresses
    if len(results) % 100 == 0:
    	logger.info("Completed {} of {} address".format(len(results), len(addresses)))
            
    # Every 500 addresses, save progress to file(in case of a failure so you have something!)
    if len(results) % 500 == 0:
        pd.DataFrame(results).to_csv("{}_bak".format(output_filename))

# All done
logger.info("Finished geocoding all addresses")
# Write the full results to csv using the pandas library.
pd.DataFrame(results).to_csv(output_filename, encoding='utf8')
# Out:
# Geocoded: 305 West Broadway Suite 147,  New York, NY 10013: OK
# Geocoded: 305 West Broadway Suite 147,  New York, NY 10013: OK
# Geocoded: 305 West Broadway Suite 147,  New York, NY 10013: OK
# Geocoded: 305 West Broadway Suite 147,  New York, NY 10013: OK
# Geocoded: 305 West Broadway Suite 147,  New York, NY 10013: OK
# Geocoded: 731 Market Street, 200, San Francisco, California 94103, US: OK
# Geocoded: 731 Market Street, 200, San Francisco, California 94103, US: OK
# Geocoded: 731 Market Street, 200, San Francisco, California 94103, US: OK
# Geocoded: 731 Market Street, 200, San Francisco, California 94103, US: OK
# Geocoded: 731 Market Street, 200, San Francisco, California 94103, US: OK
# Geocoded: Prime Tower, Hardstrasse 201, 8005 Zürich, Switzerland: OK
# Geocoded: Prime Tower, Hardstrasse 201, 8005 Zürich, Switzerland: OK
# Geocoded: Prime Tower, Hardstrasse 201, 8005 Zürich, Switzerland: OK
# Geocoded: Prime Tower, Hardstrasse 201, 8005 Zürich, Switzerland: OK
# Geocoded: Prime Tower, Hardstrasse 201, 8005 Zürich, Switzerland: OK
# Geocoded: Marktstrasse 32 – 34, 65428 Rüsselsheim am Main, Germany: OK
# Geocoded: Marktstrasse 32 – 34, 65428 Rüsselsheim am Main, Germany: OK
# Geocoded: Marktstrasse 32 – 34, 65428 Rüsselsheim am Main, Germany: OK
# Geocoded: Marktstrasse 32 – 34, 65428 Rüsselsheim am Main, Germany: OK
# Geocoded: Marktstrasse 32 – 34, 65428 Rüsselsheim am Main, Germany: OK
# Geocoded: 7290 Virginia Parkway Suite 3000, McKinney, TX 75071, United States: OK
# Geocoded: 7290 Virginia Parkway Suite 3000, McKinney, TX 75071, United States: OK
# Geocoded: 7290 Virginia Parkway Suite 3000, McKinney, TX 75071, United States: OK
# Geocoded: 7290 Virginia Parkway Suite 3000, McKinney, TX 75071, United States: OK
# Geocoded: 7290 Virginia Parkway Suite 3000, McKinney, TX 75071, United States: OK
# Geocoded: Torsgatan 26, 113 21 Stockholm, Sweden: OK
# Geocoded: Torsgatan 26, 113 21 Stockholm, Sweden: OK
# Geocoded: Torsgatan 26, 113 21 Stockholm, Sweden: OK
# Geocoded: Torsgatan 26, 113 21 Stockholm, Sweden: OK
# Geocoded: Torsgatan 26, 113 21 Stockholm, Sweden: OK
# Geocoded: 18100 Von Karman Ave, Ste 100, Irvine, California 92612, US: OK
# Geocoded: 18100 Von Karman Ave, Ste 100, Irvine, California 92612, US: OK
# Geocoded: 18100 Von Karman Ave, Ste 100, Irvine, California 92612, US: OK
# Geocoded: 18100 Von Karman Ave, Ste 100, Irvine, California 92612, US: OK
# Geocoded: 18100 Von Karman Ave, Ste 100, Irvine, California 92612, US: OK
# Geocoded: 203 Crescent St, Waltham, Massachusetts 02453, US: OK
# Geocoded: 203 Crescent St, Waltham, Massachusetts 02453, US: OK
# Geocoded: 203 Crescent St, Waltham, Massachusetts 02453, US: OK
# Geocoded: 203 Crescent St, Waltham, Massachusetts 02453, US: OK
# Geocoded: 203 Crescent St, Waltham, Massachusetts 02453, US: OK
# Geocoded: 1155 Perimeter Center W, Sandy Springs, Georgia 30338, US: OK
# Geocoded: 1155 Perimeter Center W, Sandy Springs, Georgia 30338, US: OK
# Geocoded: 1155 Perimeter Center W, Sandy Springs, Georgia 30338, US: OK
# Geocoded: 1155 Perimeter Center W, Sandy Springs, Georgia 30338, US: OK
# Geocoded: 1155 Perimeter Center W, Sandy Springs, Georgia 30338, US: OK
# Geocoded: 498 7th Avenue, New York, NY 10018, US: OK
# Geocoded: 498 7th Avenue, New York, NY 10018, US: OK
# Geocoded: 498 7th Avenue, New York, NY 10018, US: OK
# Geocoded: 498 7th Avenue, New York, NY 10018, US: OK
# Geocoded: 498 7th Avenue, New York, NY 10018, US: OK
# Geocoded: Miguel Hidalgo, Mexico City 11550, MX: OK
# Geocoded: Miguel Hidalgo, Mexico City 11550, MX: OK
# Geocoded: Miguel Hidalgo, Mexico City 11550, MX: OK
# Geocoded: Miguel Hidalgo, Mexico City 11550, MX: OK
# Geocoded: Miguel Hidalgo, Mexico City 11550, MX: OK
# Geocoded: 154 Grand Street, New York, New York, 10013, United States: OK
# Geocoded: 154 Grand Street, New York, New York, 10013, United States: OK
# Geocoded: 154 Grand Street, New York, New York, 10013, United States: OK
# Geocoded: 154 Grand Street, New York, New York, 10013, United States: OK
# Geocoded: 154 Grand Street, New York, New York, 10013, United States: OK
# Geocoded: 6736 Tilghman Street, Allentown, PA 18106: OK
# Geocoded: 6736 Tilghman Street, Allentown, PA 18106: OK
# Geocoded: 6736 Tilghman Street, Allentown, PA 18106: OK
# Geocoded: 6736 Tilghman Street, Allentown, PA 18106: OK
# Geocoded: 6736 Tilghman Street, Allentown, PA 18106: OK
# Geocoded: 900 Terminal Rd Dock Door 243, Ft Worth, TX 76106: OK
# Geocoded: 900 Terminal Rd Dock Door 243, Ft Worth, TX 76106: OK
# Geocoded: 900 Terminal Rd Dock Door 243, Ft Worth, TX 76106: OK
# Geocoded: 900 Terminal Rd Dock Door 243, Ft Worth, TX 76106: OK
# Geocoded: 900 Terminal Rd Dock Door 243, Ft Worth, TX 76106: OK
# Geocoded: 1501 Haines St, Jacksonville, FL 32206: OK
# Geocoded: 1501 Haines St, Jacksonville, FL 32206: OK
# Geocoded: 1501 Haines St, Jacksonville, FL 32206: OK
# Geocoded: 1501 Haines St, Jacksonville, FL 32206: OK
# Geocoded: 1501 Haines St, Jacksonville, FL 32206: OK
# Geocoded: 3195 E Washburn Rd, Unit 100, North Las Vegas, NV 89081: OK
# Geocoded: 3195 E Washburn Rd, Unit 100, North Las Vegas, NV 89081: OK
# Geocoded: 3195 E Washburn Rd, Unit 100, North Las Vegas, NV 89081: OK
# Geocoded: 3195 E Washburn Rd, Unit 100, North Las Vegas, NV 89081: OK
# Geocoded: 3195 E Washburn Rd, Unit 100, North Las Vegas, NV 89081: OK
# Geocoded: 2507 S 300 W, Salt Lake City, UT 84115: OK
# Geocoded: 2507 S 300 W, Salt Lake City, UT 84115: OK
# Geocoded: 2507 S 300 W, Salt Lake City, UT 84115: OK
# Geocoded: 2507 S 300 W, Salt Lake City, UT 84115: OK
# Geocoded: 2507 S 300 W, Salt Lake City, UT 84115: OK
# Geocoded: 5900, 14th Avenue, Markham, ON L3S 4K4: OK
# Geocoded: 5900, 14th Avenue, Markham, ON L3S 4K4: OK
# Geocoded: 5900, 14th Avenue, Markham, ON L3S 4K4: OK
# Geocoded: 5900, 14th Avenue, Markham, ON L3S 4K4: OK
# Geocoded: 5900, 14th Avenue, Markham, ON L3S 4K4: OK
# Geocoded: 50 Executive Pkwy, Hudson, OH 44236, United States: OK
# Geocoded: 50 Executive Pkwy, Hudson, OH 44236, United States: OK
# Geocoded: 50 Executive Pkwy, Hudson, OH 44236, United States: OK
# Geocoded: 50 Executive Pkwy, Hudson, OH 44236, United States: OK
# Geocoded: 50 Executive Pkwy, Hudson, OH 44236, United States: OK
# Geocoded: Heinz-Nixdorf-Ring 1, 33106 Paderborn , Germany: OK
# Geocoded: Heinz-Nixdorf-Ring 1, 33106 Paderborn , Germany: OK
# Geocoded: Heinz-Nixdorf-Ring 1, 33106 Paderborn , Germany: OK
# Geocoded: Heinz-Nixdorf-Ring 1, 33106 Paderborn , Germany: OK
# Geocoded: Heinz-Nixdorf-Ring 1, 33106 Paderborn , Germany: OK
# Geocoded: 2859 Paces Ferry Rd SE, Suite 1800, Atlanta, GA 30339: OK
# Geocoded: 2859 Paces Ferry Rd SE, Suite 1800, Atlanta, GA 30339: OK
# Geocoded: 2859 Paces Ferry Rd SE, Suite 1800, Atlanta, GA 30339: OK
# Geocoded: 2859 Paces Ferry Rd SE, Suite 1800, Atlanta, GA 30339: OK
# Geocoded: 2859 Paces Ferry Rd SE, Suite 1800, Atlanta, GA 30339: OK
# Geocoded: Rue B Section 21, Ilot 58, lot 94 local A, Hydra, 16035, Alger, Algeria: OK
# Geocoded: Rue B Section 21, Ilot 58, lot 94 local A, Hydra, 16035, Alger, Algeria: OK
# Geocoded: Rue B Section 21, Ilot 58, lot 94 local A, Hydra, 16035, Alger, Algeria: OK
# Geocoded: Rue B Section 21, Ilot 58, lot 94 local A, Hydra, 16035, Alger, Algeria: OK
# Geocoded: Rue B Section 21, Ilot 58, lot 94 local A, Hydra, 16035, Alger, Algeria: OK
# Geocoded: Ground Floor, Building C, 1 Homebush Bay Drive, Rhodes NSW 2138: OK
# Geocoded: Ground Floor, Building C, 1 Homebush Bay Drive, Rhodes NSW 2138: OK
# Geocoded: Ground Floor, Building C, 1 Homebush Bay Drive, Rhodes NSW 2138: OK
# Geocoded: Ground Floor, Building C, 1 Homebush Bay Drive, Rhodes NSW 2138: OK
# Geocoded: Ground Floor, Building C, 1 Homebush Bay Drive, Rhodes NSW 2138: OK
# Geocoded: Modecenterstraße 17-19, 1110 Vienna: OK
# Geocoded: Modecenterstraße 17-19, 1110 Vienna: OK
# Geocoded: Modecenterstraße 17-19, 1110 Vienna: OK
# Geocoded: Modecenterstraße 17-19, 1110 Vienna: OK
# Geocoded: Modecenterstraße 17-19, 1110 Vienna: OK
# Geocoded: Brusselsesteenweg 494, B-1731 Zellik, Belgium: OK
# Geocoded: Brusselsesteenweg 494, B-1731 Zellik, Belgium: OK
# Geocoded: Brusselsesteenweg 494, B-1731 Zellik, Belgium: OK
# Geocoded: Brusselsesteenweg 494, B-1731 Zellik, Belgium: OK
# Geocoded: Brusselsesteenweg 494, B-1731 Zellik, Belgium: OK
# Geocoded: J.Cardijnstraat, 14/16, B-9420 Erpe-Mere, Belgium: OK
# Geocoded: J.Cardijnstraat, 14/16, B-9420 Erpe-Mere, Belgium: OK
# Geocoded: J.Cardijnstraat, 14/16, B-9420 Erpe-Mere, Belgium: OK
# Geocoded: J.Cardijnstraat, 14/16, B-9420 Erpe-Mere, Belgium: OK
# Geocoded: J.Cardijnstraat, 14/16, B-9420 Erpe-Mere, Belgium: OK
# Geocoded: 1350 Francisco Matarazzo Avenue, São Paulo, SP, Zip Code: 05001-100, Brazil: OK
# Geocoded: 1350 Francisco Matarazzo Avenue, São Paulo, SP, Zip Code: 05001-100, Brazil: OK
# Geocoded: 1350 Francisco Matarazzo Avenue, São Paulo, SP, Zip Code: 05001-100, Brazil: OK
# Geocoded: 1350 Francisco Matarazzo Avenue, São Paulo, SP, Zip Code: 05001-100, Brazil: OK
# Geocoded: 1350 Francisco Matarazzo Avenue, São Paulo, SP, Zip Code: 05001-100, Brazil: OK
# Geocoded: 300 Wellington St, London, ON N6B 2L5: OK
# Geocoded: 300 Wellington St, London, ON N6B 2L5: OK
# Geocoded: 300 Wellington St, London, ON N6B 2L5: OK
# Geocoded: 300 Wellington St, London, ON N6B 2L5: OK
# Geocoded: 300 Wellington St, London, ON N6B 2L5: OK
# Geocoded: 6630 Campobello Road, Mississauga, ON L5N 2L8: OK
# Geocoded: 6630 Campobello Road, Mississauga, ON L5N 2L8: OK
# Geocoded: 6630 Campobello Road, Mississauga, ON L5N 2L8: OK
# Geocoded: 6630 Campobello Road, Mississauga, ON L5N 2L8: OK
# Geocoded: 6630 Campobello Road, Mississauga, ON L5N 2L8: OK
# Geocoded: 10F, Huasting Building, No.88, Lane 777, West Guangzhong Road, Shanghai P.R., China 200072: OK
# Geocoded: 10F, Huasting Building, No.88, Lane 777, West Guangzhong Road, Shanghai P.R., China 200072: OK
# Geocoded: 10F, Huasting Building, No.88, Lane 777, West Guangzhong Road, Shanghai P.R., China 200072: OK
# Geocoded: 10F, Huasting Building, No.88, Lane 777, West Guangzhong Road, Shanghai P.R., China 200072: OK
# Geocoded: 10F, Huasting Building, No.88, Lane 777, West Guangzhong Road, Shanghai P.R., China 200072: OK
# Geocoded: Siemensova 2, 155 00 Prague 13 - Stodulky, Czech Republic: OK
# Geocoded: Siemensova 2, 155 00 Prague 13 - Stodulky, Czech Republic: OK
# Geocoded: Siemensova 2, 155 00 Prague 13 - Stodulky, Czech Republic: OK
# Geocoded: Siemensova 2, 155 00 Prague 13 - Stodulky, Czech Republic: OK
# Geocoded: Siemensova 2, 155 00 Prague 13 - Stodulky, Czech Republic: OK
# Geocoded: Fabriksparken 20, 2600 Glostrup: OK
# Geocoded: Fabriksparken 20, 2600 Glostrup: OK
# Geocoded: Fabriksparken 20, 2600 Glostrup: OK
# Geocoded: Fabriksparken 20, 2600 Glostrup: OK
# Geocoded: Fabriksparken 20, 2600 Glostrup: OK
# Geocoded: Building 10, Karakaari 5 E, 02610 Espoo, Finland: OK
# Geocoded: Building 10, Karakaari 5 E, 02610 Espoo, Finland: OK
# Geocoded: Building 10, Karakaari 5 E, 02610 Espoo, Finland: OK
# Geocoded: Building 10, Karakaari 5 E, 02610 Espoo, Finland: OK
# Geocoded: Building 10, Karakaari 5 E, 02610 Espoo, Finland: OK
# Geocoded: 6, avenue Morane Saulnier, 78140 Vélizy Villacoublay, France: OK
# Geocoded: 6, avenue Morane Saulnier, 78140 Vélizy Villacoublay, France: OK
# Geocoded: 6, avenue Morane Saulnier, 78140 Vélizy Villacoublay, France: OK
# Geocoded: 6, avenue Morane Saulnier, 78140 Vélizy Villacoublay, France: OK
# Geocoded: 6, avenue Morane Saulnier, 78140 Vélizy Villacoublay, France: OK
# Geocoded: Wohlrabedamm 31, 13629 Berlin: OK
# Geocoded: Wohlrabedamm 31, 13629 Berlin: OK
# Geocoded: Wohlrabedamm 31, 13629 Berlin: OK
# Geocoded: Wohlrabedamm 31, 13629 Berlin: OK
# Geocoded: Wohlrabedamm 31, 13629 Berlin: OK
# Geocoded: 14th km. Athens – Lamia Nat. Road, 14564 Kifissia, Athens, Greece: OK
# Geocoded: 14th km. Athens – Lamia Nat. Road, 14564 Kifissia, Athens, Greece: OK
# Geocoded: 14th km. Athens – Lamia Nat. Road, 14564 Kifissia, Athens, Greece: OK
# Geocoded: 14th km. Athens – Lamia Nat. Road, 14564 Kifissia, Athens, Greece: OK
# Geocoded: 14th km. Athens – Lamia Nat. Road, 14564 Kifissia, Athens, Greece: OK
# Geocoded: Units 2506-08, 25/F., Tower 2, Ever Gain Plaza, 88 Container Port Road, Kwai Chung, New Territories, Hong Kong: OK
# Geocoded: Units 2506-08, 25/F., Tower 2, Ever Gain Plaza, 88 Container Port Road, Kwai Chung, New Territories, Hong Kong: OK
# Geocoded: Units 2506-08, 25/F., Tower 2, Ever Gain Plaza, 88 Container Port Road, Kwai Chung, New Territories, Hong Kong: OK
# Geocoded: Units 2506-08, 25/F., Tower 2, Ever Gain Plaza, 88 Container Port Road, Kwai Chung, New Territories, Hong Kong: OK
# Geocoded: Units 2506-08, 25/F., Tower 2, Ever Gain Plaza, 88 Container Port Road, Kwai Chung, New Territories, Hong Kong: OK
# Geocoded: H-2220 Vecsés, JT ROSS PARK/AEROZONE, L?rinci út 59, Building C3: OK
# Geocoded: H-2220 Vecsés, JT ROSS PARK/AEROZONE, L?rinci út 59, Building C3: OK
# Geocoded: H-2220 Vecsés, JT ROSS PARK/AEROZONE, L?rinci út 59, Building C3: OK
# Geocoded: Z.A. Op Zaemer 43-45, L-4959 Bascharage, Luxembourg: OK
# Geocoded: Z.A. Op Zaemer 43-45, L-4959 Bascharage, Luxembourg: OK
# Geocoded: Level 10, Block K Solaris Mont Kiara, No 2 Jalan Solaris, 50480 Kuala Lumpur, Malaysia: OK
# Geocoded: Level 10, Block K Solaris Mont Kiara, No 2 Jalan Solaris, 50480 Kuala Lumpur, Malaysia: OK
# Geocoded: Level 10, Block K Solaris Mont Kiara, No 2 Jalan Solaris, 50480 Kuala Lumpur, Malaysia: OK
# Geocoded: Level 10, Block K Solaris Mont Kiara, No 2 Jalan Solaris, 50480 Kuala Lumpur, Malaysia: OK
# Geocoded: Level 10, Block K Solaris Mont Kiara, No 2 Jalan Solaris, 50480 Kuala Lumpur, Malaysia: OK
# Geocoded: Av. Paseo de la Reforma 296, Juárez, Cuauhtémoc, 06600 Ciudad de Mexico, CDMX: OK
# Geocoded: Av. Paseo de la Reforma 296, Juárez, Cuauhtémoc, 06600 Ciudad de Mexico, CDMX: OK
# Geocoded: Av. Paseo de la Reforma 296, Juárez, Cuauhtémoc, 06600 Ciudad de Mexico, CDMX: OK
# Geocoded: Av. Paseo de la Reforma 296, Juárez, Cuauhtémoc, 06600 Ciudad de Mexico, CDMX: OK
# Geocoded: Av. Paseo de la Reforma 296, Juárez, Cuauhtémoc, 06600 Ciudad de Mexico, CDMX: OK
# Geocoded: Prolongacion Boulevard, Bernardo Quintana Sur N0. 302 Manzana, Queretaro, Mexico: OK
# Geocoded: Prolongacion Boulevard, Bernardo Quintana Sur N0. 302 Manzana, Queretaro, Mexico: OK
# Geocoded: Prolongacion Boulevard, Bernardo Quintana Sur N0. 302 Manzana, Queretaro, Mexico: OK
# Geocoded: Prolongacion Boulevard, Bernardo Quintana Sur N0. 302 Manzana, Queretaro, Mexico: OK
# Geocoded: Prolongacion Boulevard, Bernardo Quintana Sur N0. 302 Manzana, Queretaro, Mexico: OK
# Geocoded: Rez de chaussée, Imm Tour Ouest Anfa place, 20000 Casablanca, Morocco: OK
# Geocoded: Rez de chaussée, Imm Tour Ouest Anfa place, 20000 Casablanca, Morocco: OK
# Geocoded: Rez de chaussée, Imm Tour Ouest Anfa place, 20000 Casablanca, Morocco: OK
# Geocoded: Rez de chaussée, Imm Tour Ouest Anfa place, 20000 Casablanca, Morocco: OK
# Geocoded: Rez de chaussée, Imm Tour Ouest Anfa place, 20000 Casablanca, Morocco: OK
# Geocoded: Unit F, MIMOSA Building Ground Floor, 196A, West Shwe Gone Taine 5th Street, Bahan Township, Yangon, Myanmar.: OK
# Geocoded: Unit F, MIMOSA Building Ground Floor, 196A, West Shwe Gone Taine 5th Street, Bahan Township, Yangon, Myanmar.: OK
# Geocoded: Unit F, MIMOSA Building Ground Floor, 196A, West Shwe Gone Taine 5th Street, Bahan Township, Yangon, Myanmar.: OK
# Geocoded: Unit F, MIMOSA Building Ground Floor, 196A, West Shwe Gone Taine 5th Street, Bahan Township, Yangon, Myanmar.: OK
# Geocoded: Unit F, MIMOSA Building Ground Floor, 196A, West Shwe Gone Taine 5th Street, Bahan Township, Yangon, Myanmar.: OK
# Geocoded: Papendorpseweg 100, 3528 BJ Utrecht, The Netherlands: OK
# Geocoded: Papendorpseweg 100, 3528 BJ Utrecht, The Netherlands: OK
# Geocoded: Papendorpseweg 100, 3528 BJ Utrecht, The Netherlands: OK
# Geocoded: Papendorpseweg 100, 3528 BJ Utrecht, The Netherlands: OK
# Geocoded: Papendorpseweg 100, 3528 BJ Utrecht, The Netherlands: OK
# Geocoded: Innspurten 1A, 0663 OSLO, PO box: Postboks 6734 Etterstad, 0609 Oslo: OK
# Geocoded: Innspurten 1A, 0663 OSLO, PO box: Postboks 6734 Etterstad, 0609 Oslo: OK
# Geocoded: Innspurten 1A, 0663 OSLO, PO box: Postboks 6734 Etterstad, 0609 Oslo: OK
# Geocoded: Innspurten 1A, 0663 OSLO, PO box: Postboks 6734 Etterstad, 0609 Oslo: OK
# Geocoded: Innspurten 1A, 0663 OSLO, PO box: Postboks 6734 Etterstad, 0609 Oslo: OK
# Geocoded: 33F Rufino Towers, 6784 Ayala Avenue Corner, Rufino Street, Makati City 1226: OK
# Geocoded: 33F Rufino Towers, 6784 Ayala Avenue Corner, Rufino Street, Makati City 1226: OK
# Geocoded: 33F Rufino Towers, 6784 Ayala Avenue Corner, Rufino Street, Makati City 1226: OK
# Geocoded: 33F Rufino Towers, 6784 Ayala Avenue Corner, Rufino Street, Makati City 1226: OK
# Geocoded: 33F Rufino Towers, 6784 Ayala Avenue Corner, Rufino Street, Makati City 1226: OK
# Geocoded: Brynów Center, ul. Gawronów 4, 40-527 Katowice: OK
# Geocoded: Brynów Center, ul. Gawronów 4, 40-527 Katowice: OK
# Geocoded: Brynów Center, ul. Gawronów 4, 40-527 Katowice: OK
# Geocoded: Brynów Center, ul. Gawronów 4, 40-527 Katowice: OK
# Geocoded: Brynów Center, ul. Gawronów 4, 40-527 Katowice: OK
# Geocoded: West Station II, Al. Jerozolimskie 142B, 02-305 Warszawa: OK
# Geocoded: West Station II, Al. Jerozolimskie 142B, 02-305 Warszawa: OK
# Geocoded: West Station II, Al. Jerozolimskie 142B, 02-305 Warszawa: OK
# Geocoded: West Station II, Al. Jerozolimskie 142B, 02-305 Warszawa: OK
# Geocoded: West Station II, Al. Jerozolimskie 142B, 02-305 Warszawa: OK
# Geocoded: Rua Nossa Senhora da, Conceição, 5, 2794-086 Carnaxide, Portugal: OK
# Geocoded: Rua Nossa Senhora da, Conceição, 5, 2794-086 Carnaxide, Portugal: OK
# Geocoded: Rua Nossa Senhora da, Conceição, 5, 2794-086 Carnaxide, Portugal: OK
# Geocoded: Rua Nossa Senhora da, Conceição, 5, 2794-086 Carnaxide, Portugal: OK
# Geocoded: Rua Nossa Senhora da, Conceição, 5, 2794-086 Carnaxide, Portugal: OK
# Geocoded: 24 Delea Veche Str, Building A, 7th floor, Bucharest 2, Romania: OK
# Geocoded: 24 Delea Veche Str, Building A, 7th floor, Bucharest 2, Romania: OK
# Geocoded: 24 Delea Veche Str, Building A, 7th floor, Bucharest 2, Romania: OK
# Geocoded: 24 Delea Veche Str, Building A, 7th floor, Bucharest 2, Romania: OK
# Geocoded: 24 Delea Veche Str, Building A, 7th floor, Bucharest 2, Romania: OK
# Error geocoding 30A Kallang Place #04-01, Singapore 339213: REQUEST_DENIED
#
# Geocoded: 2110 Austin Ave, Rochester, Michigan 48309, US: OK
# Geocoded: 2110 Austin Ave, Rochester, Michigan 48309, US: OK
# Geocoded: 2110 Austin Ave, Rochester, Michigan 48309, US: OK
# Geocoded: 2110 Austin Ave, Rochester, Michigan 48309, US: OK
# Geocoded: 2110 Austin Ave, Rochester, Michigan 48309, US: OK
# Geocoded: 444 Castro St, Mountain View, California, US: OK
# Geocoded: 444 Castro St, Mountain View, California, US: OK
# Geocoded: 444 Castro St, Mountain View, California, US: OK
# Geocoded: 444 Castro St, Mountain View, California, US: OK
# Geocoded: 444 Castro St, Mountain View, California, US: OK
# Geocoded: Córdoba 49, Ciudad de México, Cuauhtémoc 06700, MX: OK
# Geocoded: Córdoba 49, Ciudad de México, Cuauhtémoc 06700, MX: OK
# Geocoded: Córdoba 49, Ciudad de México, Cuauhtémoc 06700, MX: OK
# Geocoded: Córdoba 49, Ciudad de México, Cuauhtémoc 06700, MX: OK
# Geocoded: Córdoba 49, Ciudad de México, Cuauhtémoc 06700, MX: OK
# Geocoded: 1944 Avenida Alfredo Benavides, Miraflores, Lima 15048, PE: OK
# Geocoded: 1944 Avenida Alfredo Benavides, Miraflores, Lima 15048, PE: OK
# Geocoded: 1944 Avenida Alfredo Benavides, Miraflores, Lima 15048, PE: OK
# Geocoded: 1944 Avenida Alfredo Benavides, Miraflores, Lima 15048, PE: OK
# Geocoded: 1944 Avenida Alfredo Benavides, Miraflores, Lima 15048, PE: OK
# Geocoded: Avenida Holanda 100, Oficina 606, Providencia, Región Metropolitana de Santiago 7510021, CL: OK
# Geocoded: Avenida Holanda 100, Oficina 606, Providencia, Región Metropolitana de Santiago 7510021, CL: OK
# Geocoded: Avenida Holanda 100, Oficina 606, Providencia, Región Metropolitana de Santiago 7510021, CL: OK
# Geocoded: Avenida Holanda 100, Oficina 606, Providencia, Región Metropolitana de Santiago 7510021, CL: OK
# Geocoded: Avenida Holanda 100, Oficina 606, Providencia, Región Metropolitana de Santiago 7510021, CL: OK
# Geocoded: Roque Graseras 694, Montevideo, Montevideo, UY: OK
# Geocoded: Roque Graseras 694, Montevideo, Montevideo, UY: OK
# Geocoded: Roque Graseras 694, Montevideo, Montevideo, UY: OK
# Geocoded: Roque Graseras 694, Montevideo, Montevideo, UY: OK
# Geocoded: Roque Graseras 694, Montevideo, Montevideo, UY: OK
# Geocoded: 18200 Cascade Avenue S. Seattle, WA 98188: OK
# Geocoded: 18200 Cascade Avenue S. Seattle, WA 98188: OK
# Geocoded: 18200 Cascade Avenue S. Seattle, WA 98188: OK
# Geocoded: 18200 Cascade Avenue S. Seattle, WA 98188: OK
# Geocoded: 18200 Cascade Avenue S. Seattle, WA 98188: OK
# Geocoded: 475 Horizon Drive, Suwanee, GA 30024: OK
# Geocoded: 475 Horizon Drive, Suwanee, GA 30024: OK
# Geocoded: 475 Horizon Drive, Suwanee, GA 30024: OK
# Geocoded: 475 Horizon Drive, Suwanee, GA 30024: OK
# Geocoded: 475 Horizon Drive, Suwanee, GA 30024: OK
# Geocoded: 821 2nd Avenue, Seattle, WA 98104 suite 500: OK
# Geocoded: 821 2nd Avenue, Seattle, WA 98104 suite 500: OK
# Geocoded: 821 2nd Avenue, Seattle, WA 98104 suite 500: OK
# Geocoded: 821 2nd Avenue, Seattle, WA 98104 suite 500: OK
# Geocoded: 821 2nd Avenue, Seattle, WA 98104 suite 500: OK
# Geocoded: 15950 N 76th St, Scottsdale, Arizona 85260, US: OK
# Geocoded: 15950 N 76th St, Scottsdale, Arizona 85260, US: OK
# Geocoded: 15950 N 76th St, Scottsdale, Arizona 85260, US: OK
# Geocoded: 15950 N 76th St, Scottsdale, Arizona 85260, US: OK
# Geocoded: 15950 N 76th St, Scottsdale, Arizona 85260, US: OK
# Geocoded: 1160 Battery Street, East Suite 100, San Francisco, California 94111: OK
# Geocoded: 1160 Battery Street, East Suite 100, San Francisco, California 94111: OK
# Geocoded: 1160 Battery Street, East Suite 100, San Francisco, California 94111: OK
# Geocoded: 1160 Battery Street, East Suite 100, San Francisco, California 94111: OK
# Geocoded: 1160 Battery Street, East Suite 100, San Francisco, California 94111: OK
# Geocoded: 4 Armstrong Road, Suite 210, Shelton, CT 06484: OK
# Geocoded: 4 Armstrong Road, Suite 210, Shelton, CT 06484: OK
# Geocoded: 4 Armstrong Road, Suite 210, Shelton, CT 06484: OK
# Geocoded: 4 Armstrong Road, Suite 210, Shelton, CT 06484: OK
# Geocoded: 4 Armstrong Road, Suite 210, Shelton, CT 06484: OK
# Geocoded: 2a Charing Cross Rd, Charing Cross, London WC2H 0HF, United Kingdom: OK
# Geocoded: 2a Charing Cross Rd, Charing Cross, London WC2H 0HF, United Kingdom: OK
# Geocoded: 2a Charing Cross Rd, Charing Cross, London WC2H 0HF, United Kingdom: OK
# Geocoded: 2a Charing Cross Rd, Charing Cross, London WC2H 0HF, United Kingdom: OK
# Geocoded: 2a Charing Cross Rd, Charing Cross, London WC2H 0HF, United Kingdom: OK
# Geocoded: 175 Varick Street, Suite 529, New York, NY 10014: OK
# Geocoded: 175 Varick Street, Suite 529, New York, NY 10014: OK
# Geocoded: 175 Varick Street, Suite 529, New York, NY 10014: OK
# Geocoded: 175 Varick Street, Suite 529, New York, NY 10014: OK
# Geocoded: 175 Varick Street, Suite 529, New York, NY 10014: OK
# Completed 100 of 247 address
# Completed 100 of 247 address
# Completed 100 of 247 address
# Completed 100 of 247 address
# Completed 100 of 247 address
# Geocoded: Bogotá, Cundinamarca 110111, CO: OK
# Geocoded: Bogotá, Cundinamarca 110111, CO: OK
# Geocoded: Bogotá, Cundinamarca 110111, CO: OK
# Geocoded: Bogotá, Cundinamarca 110111, CO: OK
# Geocoded: Bogotá, Cundinamarca 110111, CO: OK
# Geocoded: Köpenicker Straße 125, Berlin, BE 10179, DE: OK
# Geocoded: Köpenicker Straße 125, Berlin, BE 10179, DE: OK
# Geocoded: Köpenicker Straße 125, Berlin, BE 10179, DE: OK
# Geocoded: Köpenicker Straße 125, Berlin, BE 10179, DE: OK
# Geocoded: Köpenicker Straße 125, Berlin, BE 10179, DE: OK
# Geocoded: 25 Walbrook, Walbrook, City of London, London EC4N 8AF, England, United Kingdom: OK
# Geocoded: 10545, Hardin Valley Road, Knoxville, TENNESSEE 37932, US: OK
# Geocoded: 10545, Hardin Valley Road, Knoxville, TENNESSEE 37932, US: OK
# Geocoded: 10545, Hardin Valley Road, Knoxville, TENNESSEE 37932, US: OK
# Geocoded: 10545, Hardin Valley Road, Knoxville, TENNESSEE 37932, US: OK
# Geocoded: 10545, Hardin Valley Road, Knoxville, TENNESSEE 37932, US: OK
# Geocoded: 11555 N. Meridian St., Suite 300, Carmel, IN 46032, US: OK
# Geocoded: 11555 N. Meridian St., Suite 300, Carmel, IN 46032, US: OK
# Geocoded: 11555 N. Meridian St., Suite 300, Carmel, IN 46032, US: OK
# Geocoded: 11555 N. Meridian St., Suite 300, Carmel, IN 46032, US: OK
# Geocoded: 11555 N. Meridian St., Suite 300, Carmel, IN 46032, US: OK
# Geocoded: 18089 Edison Ave, Chesterfield, MO 63005, United States: OK
# Geocoded: 18089 Edison Ave, Chesterfield, MO 63005, United States: OK
# Geocoded: 18089 Edison Ave, Chesterfield, MO 63005, United States: OK
# Geocoded: 18089 Edison Ave, Chesterfield, MO 63005, United States: OK
# Geocoded: 18089 Edison Ave, Chesterfield, MO 63005, United States: OK
# Geocoded: 4905 Research Dr NW, Huntsville, AL 35805, United States: OK
# Geocoded: 4905 Research Dr NW, Huntsville, AL 35805, United States: OK
# Geocoded: 4905 Research Dr NW, Huntsville, AL 35805, United States: OK
# Geocoded: 4905 Research Dr NW, Huntsville, AL 35805, United States: OK
# Geocoded: 4905 Research Dr NW, Huntsville, AL 35805, United States: OK
# Geocoded: 243 Dover Rd, Clarksville, TN 37042, United States: OK
# Geocoded: 243 Dover Rd, Clarksville, TN 37042, United States: OK
# Geocoded: 243 Dover Rd, Clarksville, TN 37042, United States: OK
# Geocoded: 243 Dover Rd, Clarksville, TN 37042, United States: OK
# Geocoded: 243 Dover Rd, Clarksville, TN 37042, United States: OK
# Geocoded: Takkebijster 3A, 4817 BL Breda, Netherlands: OK
# Geocoded: Takkebijster 3A, 4817 BL Breda, Netherlands: OK
# Geocoded: Takkebijster 3A, 4817 BL Breda, Netherlands: OK
# Geocoded: Takkebijster 3A, 4817 BL Breda, Netherlands: OK
# Geocoded: Takkebijster 3A, 4817 BL Breda, Netherlands: OK
# Geocoded: Maria-Jacobi Gasse 1/1, 1030 Vienna, Austria: OK
# Geocoded: Maria-Jacobi Gasse 1/1, 1030 Vienna, Austria: OK
# Geocoded: Maria-Jacobi Gasse 1/1, 1030 Vienna, Austria: OK
# Geocoded: Maria-Jacobi Gasse 1/1, 1030 Vienna, Austria: OK
# Geocoded: Maria-Jacobi Gasse 1/1, 1030 Vienna, Austria: OK
# Geocoded: Bajkalská 5, 83104 Bratislava, Slovakia: OK
# Geocoded: Bajkalská 5, 83104 Bratislava, Slovakia: OK
# Geocoded: Bajkalská 5, 83104 Bratislava, Slovakia: OK
# Geocoded: Bajkalská 5, 83104 Bratislava, Slovakia: OK
# Geocoded: Bajkalská 5, 83104 Bratislava, Slovakia: OK
# Geocoded: Rua Domingos José Martins 75, 3º andar, Recife, Pernambuco 50030-200, BR: OK
# Geocoded: Rua Domingos José Martins 75, 3º andar, Recife, Pernambuco 50030-200, BR: OK
# Geocoded: Rua Domingos José Martins 75, 3º andar, Recife, Pernambuco 50030-200, BR: OK
# Geocoded: Rua Domingos José Martins 75, 3º andar, Recife, Pernambuco 50030-200, BR: OK
# Geocoded: Rua Domingos José Martins 75, 3º andar, Recife, Pernambuco 50030-200, BR: OK
# Geocoded: 1651 Aviation Pl, Billings, Montana 59105-1993, US: OK
# Geocoded: 1651 Aviation Pl, Billings, Montana 59105-1993, US: OK
# Geocoded: 1651 Aviation Pl, Billings, Montana 59105-1993, US: OK
# Geocoded: 1651 Aviation Pl, Billings, Montana 59105-1993, US: OK
# Geocoded: 1651 Aviation Pl, Billings, Montana 59105-1993, US: OK
# Geocoded: 20830 N Tatum Blvd, 395, Phoenix, Arizona 85050, US: OK
# Geocoded: 20830 N Tatum Blvd, 395, Phoenix, Arizona 85050, US: OK
# Geocoded: 20830 N Tatum Blvd, 395, Phoenix, Arizona 85050, US: OK
# Geocoded: 20830 N Tatum Blvd, 395, Phoenix, Arizona 85050, US: OK
# Geocoded: 20830 N Tatum Blvd, 395, Phoenix, Arizona 85050, US: OK
# Geocoded: Garonor Ouest, Aulnay sous Bois, Ile de France 93600, FR: OK
# Geocoded: Garonor Ouest, Aulnay sous Bois, Ile de France 93600, FR: OK
# Geocoded: Garonor Ouest, Aulnay sous Bois, Ile de France 93600, FR: OK
# Geocoded: Garonor Ouest, Aulnay sous Bois, Ile de France 93600, FR: OK
# Geocoded: Garonor Ouest, Aulnay sous Bois, Ile de France 93600, FR: OK
# Geocoded: Riia 142, Tartu, Estonia: OK
# Geocoded: Riia 142, Tartu, Estonia: OK
# Geocoded: Riia 142, Tartu, Estonia: OK
# Geocoded: Riia 142, Tartu, Estonia: OK
# Geocoded: Riia 142, Tartu, Estonia: OK
# Geocoded: Blauma?a iela 22, Riga, Latvia: OK
# Geocoded: Blauma?a iela 22, Riga, Latvia: OK
# Geocoded: Blauma?a iela 22, Riga, Latvia: OK
# Geocoded: Blauma?a iela 22, Riga, Latvia: OK
# Geocoded: Blauma?a iela 22, Riga, Latvia: OK
# Geocoded: 9 liniya V.O., 34, St. Petersburg, Petersburg 199004, RU: OK
# Geocoded: 9 liniya V.O., 34, St. Petersburg, Petersburg 199004, RU: OK
# Geocoded: 9 liniya V.O., 34, St. Petersburg, Petersburg 199004, RU: OK
# Geocoded: 9 liniya V.O., 34, St. Petersburg, Petersburg 199004, RU: OK
# Geocoded: 9 liniya V.O., 34, St. Petersburg, Petersburg 199004, RU: OK
# Geocoded: Karaportti 5, Espoo, Southern Finland 02610, FI: OK
# Geocoded: Karaportti 5, Espoo, Southern Finland 02610, FI: OK
# Geocoded: Karaportti 5, Espoo, Southern Finland 02610, FI: OK
# Geocoded: Karaportti 5, Espoo, Southern Finland 02610, FI: OK
# Geocoded: Karaportti 5, Espoo, Southern Finland 02610, FI: OK
# Geocoded: Ste 104, Santa Clara: OK
# Geocoded: Ste 104, Santa Clara: OK
# Geocoded: Ste 104, Santa Clara: OK
# Geocoded: Ste 104, Santa Clara: OK
# Geocoded: Ste 104, Santa Clara: OK
# Geocoded: 19, Middle Road, Fortune Centre, Singapore.: OK
# Geocoded: 19, Middle Road, Fortune Centre, Singapore.: OK
# Geocoded: 19, Middle Road, Fortune Centre, Singapore.: OK
# Geocoded: 19, Middle Road, Fortune Centre, Singapore.: OK
# Geocoded: 19, Middle Road, Fortune Centre, Singapore.: OK
# Geocoded: B7, 12/30, OASIS Sqaure, Ara Damansara, Malaysia.: OK
# Geocoded: B7, 12/30, OASIS Sqaure, Ara Damansara, Malaysia.: OK
# Geocoded: B7, 12/30, OASIS Sqaure, Ara Damansara, Malaysia.: OK
# Geocoded: B7, 12/30, OASIS Sqaure, Ara Damansara, Malaysia.: OK
# Geocoded: B7, 12/30, OASIS Sqaure, Ara Damansara, Malaysia.: OK
# Geocoded: Calle de Marino Blas de Lezo, 46022 Valencia, Spain: OK
# Geocoded: Calle de Marino Blas de Lezo, 46022 Valencia, Spain: OK
# Geocoded: Calle de Marino Blas de Lezo, 46022 Valencia, Spain: OK
# Geocoded: Calle de Marino Blas de Lezo, 46022 Valencia, Spain: OK
# Geocoded: Calle de Marino Blas de Lezo, 46022 Valencia, Spain: OK
# Geocoded: Calle Gran Vía 28, 28013 Madrid, Spain: OK
# Geocoded: Calle Gran Vía 28, 28013 Madrid, Spain: OK
# Geocoded: Calle Gran Vía 28, 28013 Madrid, Spain: OK
# Geocoded: Calle Gran Vía 28, 28013 Madrid, Spain: OK
# Geocoded: Calle Gran Vía 28, 28013 Madrid, Spain: OK
# Geocoded: Toronto, Ontario L7A 1M1, CA: OK
# Geocoded: Toronto, Ontario L7A 1M1, CA: OK
# Geocoded: Toronto, Ontario L7A 1M1, CA: OK
# Geocoded: Toronto, Ontario L7A 1M1, CA: OK
# Geocoded: Toronto, Ontario L7A 1M1, CA: OK
# Geocoded: 1000 Circle 75 Parkway, Suite 300, Atlanta, GA 33401, United States: OK
# Geocoded: 1000 Circle 75 Parkway, Suite 300, Atlanta, GA 33401, United States: OK
# Geocoded: 1000 Circle 75 Parkway, Suite 300, Atlanta, GA 33401, United States: OK
# Geocoded: 1000 Circle 75 Parkway, Suite 300, Atlanta, GA 33401, United States: OK
# Geocoded: 1000 Circle 75 Parkway, Suite 300, Atlanta, GA 33401, United States: OK
# Geocoded: 110 W 40th Street, 11th Floor, New York, NY 10018: OK
# Geocoded: 110 W 40th Street, 11th Floor, New York, NY 10018: OK
# Geocoded: 110 W 40th Street, 11th Floor, New York, NY 10018: OK
# Geocoded: 110 W 40th Street, 11th Floor, New York, NY 10018: OK
# Geocoded: 110 W 40th Street, 11th Floor, New York, NY 10018: OK
# Geocoded: Charlottenstraße 2, 10969 Berlin, Germany: OK
# Geocoded: Charlottenstraße 2, 10969 Berlin, Germany: OK
# Geocoded: Charlottenstraße 2, 10969 Berlin, Germany: OK
# Geocoded: Charlottenstraße 2, 10969 Berlin, Germany: OK
# Geocoded: Charlottenstraße 2, 10969 Berlin, Germany: OK
# Geocoded: 3, Dorogozhitska st, room 317, Kiev, Kievska 04112, UA: OK
# Geocoded: 3, Dorogozhitska st, room 317, Kiev, Kievska 04112, UA: OK
# Geocoded: 3, Dorogozhitska st, room 317, Kiev, Kievska 04112, UA: OK
# Geocoded: 3, Dorogozhitska st, room 317, Kiev, Kievska 04112, UA: OK
# Geocoded: 3, Dorogozhitska st, room 317, Kiev, Kievska 04112, UA: OK
# Geocoded: 2/22 Allen St, Te Aro, Wellington, 6011, NZ: OK
# Geocoded: 2/22 Allen St, Te Aro, Wellington, 6011, NZ: OK
# Geocoded: 2/22 Allen St, Te Aro, Wellington, 6011, NZ: OK
# Geocoded: 2/22 Allen St, Te Aro, Wellington, 6011, NZ: OK
# Geocoded: 2/22 Allen St, Te Aro, Wellington, 6011, NZ: OK
# Geocoded: Two Embarcadero, 8th Floor, San Francisco, CA 94111: OK
# Geocoded: Two Embarcadero, 8th Floor, San Francisco, CA 94111: OK
# Geocoded: Two Embarcadero, 8th Floor, San Francisco, CA 94111: OK
# Geocoded: Two Embarcadero, 8th Floor, San Francisco, CA 94111: OK
# Geocoded: Two Embarcadero, 8th Floor, San Francisco, CA 94111: OK
# Geocoded: 43300 Southern Walk Plaza, Broadlands, VA 20148, United States: OK
# Geocoded: 43300 Southern Walk Plaza, Broadlands, VA 20148, United States: OK
# Geocoded: 43300 Southern Walk Plaza, Broadlands, VA 20148, United States: OK
# Geocoded: 43300 Southern Walk Plaza, Broadlands, VA 20148, United States: OK
# Geocoded: 43300 Southern Walk Plaza, Broadlands, VA 20148, United States: OK
# Geocoded: Av. Parc Tecnològic del Vallès, 3, 08290, Cerdanyola Del Vallès: OK
# Geocoded: Av. Parc Tecnològic del Vallès, 3, 08290, Cerdanyola Del Vallès: OK
# Geocoded: Av. Parc Tecnològic del Vallès, 3, 08290, Cerdanyola Del Vallès: OK
# Geocoded: Av. Parc Tecnològic del Vallès, 3, 08290, Cerdanyola Del Vallès: OK
# Geocoded: Av. Parc Tecnològic del Vallès, 3, 08290, Cerdanyola Del Vallès: OK
# Geocoded: Wichita, 67202, United States: OK
# Geocoded: Wichita, 67202, United States: OK
# Geocoded: Wichita, 67202, United States: OK
# Geocoded: Wichita, 67202, United States: OK
# Geocoded: Wichita, 67202, United States: OK
# Geocoded: Hollywood, 20636, United States: OK
# Geocoded: Hollywood, 20636, United States: OK
# Geocoded: Hollywood, 20636, United States: OK
# Geocoded: Hollywood, 20636, United States: OK
# Geocoded: Hollywood, 20636, United States: OK
# Geocoded: 1175 Church St, Bohemia, NY 11716, United States: OK
# Geocoded: 1175 Church St, Bohemia, NY 11716, United States: OK
# Geocoded: 1175 Church St, Bohemia, NY 11716, United States: OK
# Geocoded: 1175 Church St, Bohemia, NY 11716, United States: OK
# Geocoded: 1175 Church St, Bohemia, NY 11716, United States: OK
# Geocoded: Shelton, 06484, United States: OK
# Geocoded: Shelton, 06484, United States: OK
# Geocoded: Shelton, 06484, United States: OK
# Geocoded: Shelton, 06484, United States: OK
# Geocoded: Shelton, 06484, United States: OK
# Geocoded: 7617 Mineral Point Road, Madison, WI 53717, US: OK
# Geocoded: 7617 Mineral Point Road, Madison, WI 53717, US: OK
# Geocoded: 7617 Mineral Point Road, Madison, WI 53717, US: OK
# Geocoded: 7617 Mineral Point Road, Madison, WI 53717, US: OK
# Geocoded: 7617 Mineral Point Road, Madison, WI 53717, US: OK
# Geocoded: 7519 Standish Pl, Rockville, MD 20855, United States: OK
# Geocoded: 7519 Standish Pl, Rockville, MD 20855, United States: OK
# Geocoded: 7519 Standish Pl, Rockville, MD 20855, United States: OK
# Geocoded: 7519 Standish Pl, Rockville, MD 20855, United States: OK
# Geocoded: 7519 Standish Pl, Rockville, MD 20855, United States: OK
# Geocoded: Ha-Kharoshet 16, Or Yehuda, IL 6037584, IL: OK
# Geocoded: Ha-Kharoshet 16, Or Yehuda, IL 6037584, IL: OK
# Geocoded: Ha-Kharoshet 16, Or Yehuda, IL 6037584, IL: OK
# Geocoded: Ha-Kharoshet 16, Or Yehuda, IL 6037584, IL: OK
# Geocoded: Ha-Kharoshet 16, Or Yehuda, IL 6037584, IL: OK
# Geocoded: 48 Yonge Street, Suite 1200, Toronto, Ontario M5E1G6, CA: OK
# Geocoded: 48 Yonge Street, Suite 1200, Toronto, Ontario M5E1G6, CA: OK
# Geocoded: 48 Yonge Street, Suite 1200, Toronto, Ontario M5E1G6, CA: OK
# Geocoded: 48 Yonge Street, Suite 1200, Toronto, Ontario M5E1G6, CA: OK
# Geocoded: 48 Yonge Street, Suite 1200, Toronto, Ontario M5E1G6, CA: OK
# Finished geocoding all addresses
# Finished geocoding all addresses
# Finished geocoding all addresses
# Finished geocoding all addresses
# Finished geocoding all addresses

# %%
results = pd.read_csv("companiesgeocode.csv", encoding='utf8')
results
# Out:
#      Unnamed: 0                                  formatted_address   latitude  \
# 0             0       305 W Broadway #147, New York, NY 10013, USA  40.721500
# 1             1   731 Market St #200, San Francisco, CA 94103, USA  37.786791
# 2             2          Hardstrasse 201, 8005 Zürich, Switzerland  47.386189
# 3             3  Marktstraße 32-34, 65428 Rüsselsheim am Main, ...  49.992549
# 4             4  7290 Virginia Pkwy STE 3000, McKinney, TX 7507...  33.200849
# ..          ...                                                ...        ...
# 242         242                             Shelton, CT 06484, USA  41.316486
# 243         243      7617 Mineral Point Rd, Madison, WI 53717, USA  43.060161
# 244         244           7519 Standish Pl, Derwood, MD 20855, USA  39.109215
# 245         245              Ha-Kharoshet St 16, Or Yehuda, Israel  32.021134
# 246         246     48 Yonge St #1200, Toronto, ON M5E 1G6, Canada  43.647992
#
#       longitude     accuracy  \
# 0    -74.004274      ROOFTOP
# 1   -122.404049      ROOFTOP
# 2      8.517259      ROOFTOP
# 3      8.412541      ROOFTOP
# 4    -96.712359      ROOFTOP
# ..          ...          ...
# 242  -73.093164  APPROXIMATE
# 243  -89.514922      ROOFTOP
# 244  -77.154179      ROOFTOP
# 245   34.862667      ROOFTOP
# 246  -79.377735      ROOFTOP
#
#                                        google_place_id  \
# 0    EiwzMDUgVyBCcm9hZHdheSAjMTQ3LCBOZXcgWW9yaywgTl...
# 1                          ChIJAYZWfIiAhYARD8vpq0lI3rg
# 2                          ChIJS-n6eD8KkEcRndxIl8RnWx8
# 3                          ChIJ_SPKFi6ZvUcR-nvatxNfzeE
# 4                          ChIJq6pq-rEVTIYRCiM0jSWlo1M
# ..                                                 ...
# 242                        ChIJT3q-1TTg54kR1VNYDaydOcQ
# 243                        ChIJUTXEBAGvB4gR1LdL1CwYCOc
# 244                        ChIJ9TI3_oPSt4kRxnJd_SFSTyU
# 245                        ChIJXTQkV181HRURZ6xCyUdvv-4
# 246                        ChIJC0X8di3L1IkRh1-fgwruuRA
#
#                                 type postcode  \
# 0                         subpremise    10013
# 1                         subpremise    94103
# 2    establishment,point_of_interest     8005
# 3                     street_address    65428
# 4                         subpremise    75071
# ..                               ...      ...
# 242               locality,political    06484
# 243                          premise    53717
# 244                          premise    20855
# 245                   street_address      NaN
# 246                       subpremise  M5E 1G6
#
#                                           input_string  number_of_results  \
# 0     305 West Broadway Suite 147,  New York, NY 10013                  1
# 1    731 Market Street, 200, San Francisco, Califor...                  1
# 2    Prime Tower, Hardstrasse 201, 8005 Zürich, Swi...                  1
# 3    Marktstrasse 32 – 34, 65428 Rüsselsheim am Mai...                  1
# 4    7290 Virginia Parkway Suite 3000, McKinney, TX...                  1
# ..                                                 ...                ...
# 242                      Shelton, 06484, United States                  1
# 243     7617 Mineral Point Road, Madison, WI 53717, US                  1
# 244  7519 Standish Pl, Rockville, MD 20855, United ...                  1
# 245         Ha-Kharoshet 16, Or Yehuda, IL 6037584, IL                  1
# 246  48 Yonge Street, Suite 1200, Toronto, Ontario ...                  1
#
#     status
# 0       OK
# 1       OK
# 2       OK
# 3       OK
# 4       OK
# ..     ...
# 242     OK
# 243     OK
# 244     OK
# 245     OK
# 246     OK
#
# [247 rows x 11 columns]

# %%
data
# Out:
#            Organization Name  \
# 0             Leaf Logistics
# 1                     Shippo
# 2                    Nexxiot
# 3                    Nexxiot
# 4                    Nexxiot
# ..                       ...
# 242          Dayton T. Brown
# 243        Idle Free Systems
# 244                 Hi-G-Tek
# 245                 Hi-G-Tek
# 246  CellWand Communications
#
#                                                Address
# 0     305 West Broadway Suite 147,  New York, NY 10013
# 1    731 Market Street, 200, San Francisco, Califor...
# 2    Prime Tower, Hardstrasse 201, 8005 Zürich, Swi...
# 3    Marktstrasse 32 – 34, 65428 Rüsselsheim am Mai...
# 4    7290 Virginia Parkway Suite 3000, McKinney, TX...
# ..                                                 ...
# 242                      Shelton, 06484, United States
# 243     7617 Mineral Point Road, Madison, WI 53717, US
# 244  7519 Standish Pl, Rockville, MD 20855, United ...
# 245         Ha-Kharoshet 16, Or Yehuda, IL 6037584, IL
# 246  48 Yonge Street, Suite 1200, Toronto, Ontario ...
#
# [247 rows x 2 columns]

# %%
merged_inner = pd.merge(left=data, right=results, left_on='Address', right_on='input_string')
merged_inner
# Out:
#            Organization Name  \
# 0             Leaf Logistics
# 1                     Shippo
# 2                    Nexxiot
# 3                    Nexxiot
# 4                    Nexxiot
# ..                       ...
# 242          Dayton T. Brown
# 243        Idle Free Systems
# 244                 Hi-G-Tek
# 245                 Hi-G-Tek
# 246  CellWand Communications
#
#                                                Address  Unnamed: 0  \
# 0     305 West Broadway Suite 147,  New York, NY 10013           0
# 1    731 Market Street, 200, San Francisco, Califor...           1
# 2    Prime Tower, Hardstrasse 201, 8005 Zürich, Swi...           2
# 3    Marktstrasse 32 – 34, 65428 Rüsselsheim am Mai...           3
# 4    7290 Virginia Parkway Suite 3000, McKinney, TX...           4
# ..                                                 ...         ...
# 242                      Shelton, 06484, United States         242
# 243     7617 Mineral Point Road, Madison, WI 53717, US         243
# 244  7519 Standish Pl, Rockville, MD 20855, United ...         244
# 245         Ha-Kharoshet 16, Or Yehuda, IL 6037584, IL         245
# 246  48 Yonge Street, Suite 1200, Toronto, Ontario ...         246
#
#                                      formatted_address   latitude   longitude  \
# 0         305 W Broadway #147, New York, NY 10013, USA  40.721500  -74.004274
# 1     731 Market St #200, San Francisco, CA 94103, USA  37.786791 -122.404049
# 2            Hardstrasse 201, 8005 Zürich, Switzerland  47.386189    8.517259
# 3    Marktstraße 32-34, 65428 Rüsselsheim am Main, ...  49.992549    8.412541
# 4    7290 Virginia Pkwy STE 3000, McKinney, TX 7507...  33.200849  -96.712359
# ..                                                 ...        ...         ...
# 242                             Shelton, CT 06484, USA  41.316486  -73.093164
# 243      7617 Mineral Point Rd, Madison, WI 53717, USA  43.060161  -89.514922
# 244           7519 Standish Pl, Derwood, MD 20855, USA  39.109215  -77.154179
# 245              Ha-Kharoshet St 16, Or Yehuda, Israel  32.021134   34.862667
# 246     48 Yonge St #1200, Toronto, ON M5E 1G6, Canada  43.647992  -79.377735
#
#         accuracy                                    google_place_id  \
# 0        ROOFTOP  EiwzMDUgVyBCcm9hZHdheSAjMTQ3LCBOZXcgWW9yaywgTl...
# 1        ROOFTOP                        ChIJAYZWfIiAhYARD8vpq0lI3rg
# 2        ROOFTOP                        ChIJS-n6eD8KkEcRndxIl8RnWx8
# 3        ROOFTOP                        ChIJ_SPKFi6ZvUcR-nvatxNfzeE
# 4        ROOFTOP                        ChIJq6pq-rEVTIYRCiM0jSWlo1M
# ..           ...                                                ...
# 242  APPROXIMATE                        ChIJT3q-1TTg54kR1VNYDaydOcQ
# 243      ROOFTOP                        ChIJUTXEBAGvB4gR1LdL1CwYCOc
# 244      ROOFTOP                        ChIJ9TI3_oPSt4kRxnJd_SFSTyU
# 245      ROOFTOP                        ChIJXTQkV181HRURZ6xCyUdvv-4
# 246      ROOFTOP                        ChIJC0X8di3L1IkRh1-fgwruuRA
#
#                                 type postcode  \
# 0                         subpremise    10013
# 1                         subpremise    94103
# 2    establishment,point_of_interest     8005
# 3                     street_address    65428
# 4                         subpremise    75071
# ..                               ...      ...
# 242               locality,political    06484
# 243                          premise    53717
# 244                          premise    20855
# 245                   street_address      NaN
# 246                       subpremise  M5E 1G6
#
#                                           input_string  number_of_results  \
# 0     305 West Broadway Suite 147,  New York, NY 10013                  1
# 1    731 Market Street, 200, San Francisco, Califor...                  1
# 2    Prime Tower, Hardstrasse 201, 8005 Zürich, Swi...                  1
# 3    Marktstrasse 32 – 34, 65428 Rüsselsheim am Mai...                  1
# 4    7290 Virginia Parkway Suite 3000, McKinney, TX...                  1
# ..                                                 ...                ...
# 242                      Shelton, 06484, United States                  1
# 243     7617 Mineral Point Road, Madison, WI 53717, US                  1
# 244  7519 Standish Pl, Rockville, MD 20855, United ...                  1
# 245         Ha-Kharoshet 16, Or Yehuda, IL 6037584, IL                  1
# 246  48 Yonge Street, Suite 1200, Toronto, Ontario ...                  1
#
#     status
# 0       OK
# 1       OK
# 2       OK
# 3       OK
# 4       OK
# ..     ...
# 242     OK
# 243     OK
# 244     OK
# 245     OK
# 246     OK
#
# [247 rows x 13 columns]

# %%
cleaned_results = merged_inner[ ['Organization Name', 'formatted_address', 'latitude', 'longitude', 'status' , 'Address'] ]
cleaned_results
# Out:
#            Organization Name  \
# 0             Leaf Logistics
# 1                     Shippo
# 2                    Nexxiot
# 3                    Nexxiot
# 4                    Nexxiot
# ..                       ...
# 242          Dayton T. Brown
# 243        Idle Free Systems
# 244                 Hi-G-Tek
# 245                 Hi-G-Tek
# 246  CellWand Communications
#
#                                      formatted_address   latitude   longitude  \
# 0         305 W Broadway #147, New York, NY 10013, USA  40.721500  -74.004274
# 1     731 Market St #200, San Francisco, CA 94103, USA  37.786791 -122.404049
# 2            Hardstrasse 201, 8005 Zürich, Switzerland  47.386189    8.517259
# 3    Marktstraße 32-34, 65428 Rüsselsheim am Main, ...  49.992549    8.412541
# 4    7290 Virginia Pkwy STE 3000, McKinney, TX 7507...  33.200849  -96.712359
# ..                                                 ...        ...         ...
# 242                             Shelton, CT 06484, USA  41.316486  -73.093164
# 243      7617 Mineral Point Rd, Madison, WI 53717, USA  43.060161  -89.514922
# 244           7519 Standish Pl, Derwood, MD 20855, USA  39.109215  -77.154179
# 245              Ha-Kharoshet St 16, Or Yehuda, Israel  32.021134   34.862667
# 246     48 Yonge St #1200, Toronto, ON M5E 1G6, Canada  43.647992  -79.377735
#
#     status                                            Address
# 0       OK   305 West Broadway Suite 147,  New York, NY 10013
# 1       OK  731 Market Street, 200, San Francisco, Califor...
# 2       OK  Prime Tower, Hardstrasse 201, 8005 Zürich, Swi...
# 3       OK  Marktstrasse 32 – 34, 65428 Rüsselsheim am Mai...
# 4       OK  7290 Virginia Parkway Suite 3000, McKinney, TX...
# ..     ...                                                ...
# 242     OK                      Shelton, 06484, United States
# 243     OK     7617 Mineral Point Road, Madison, WI 53717, US
# 244     OK  7519 Standish Pl, Rockville, MD 20855, United ...
# 245     OK         Ha-Kharoshet 16, Or Yehuda, IL 6037584, IL
# 246     OK  48 Yonge Street, Suite 1200, Toronto, Ontario ...
#
# [247 rows x 6 columns]

# %%
results_denied = cleaned_results
results_denied = results_denied[ results_denied['latitude'].isnull() ]
results_denied
# Out:
#           Organization Name formatted_address  latitude  longitude  \
# 56          Diebold Nixdorf               NaN       NaN        NaN
# 175  KoiReader Technologies               NaN       NaN        NaN
# 176  KoiReader Technologies               NaN       NaN        NaN
# 177  KoiReader Technologies               NaN       NaN        NaN
# 193       Longbow Advantage               NaN       NaN        NaN
#
#               status                                           Address
# 56    REQUEST_DENIED        30A Kallang Place #04-01, Singapore 339213
# 175  INVALID_REQUEST  #153, Sector 5, HSR Layout, Bengaluru, KA 560102
# 176   REQUEST_DENIED            33 UBI Avenue 3, #08-13, Vertex 408868
# 177   REQUEST_DENIED       539 W. Commerce St. #1255, Dallas, TX 75208
# 193   REQUEST_DENIED  7250 Mile End Street #201, Montreal, QC, H2R 3A4

# %%
pd.DataFrame(results_denied).to_csv('request_denied.csv', encoding='utf8')

# %%
requestdeniedgeocoded = pd.read_csv("requestdeniedgeocoded.csv", encoding='utf8')
requestdeniedgeocoded
# Out:
#                                       given_address        lat         lon  \
# 0        30A Kallang Place #04-01, Singapore 339213   1.314741  103.865833
# 1  #153, Sector 5, HSR Layout, Bengaluru, KA 560102  12.971940   77.593690
# 2            33 UBI Avenue 3, #08-13, Vertex 408868   1.332978  103.894846
# 3       539 W. Commerce St. #1255, Dallas, TX 75208  32.773314  -96.833479
# 4  7250 Mile End Street #201, Montreal, QC, H2R 3A4  45.503182  -73.569806
#
#                                            formatted         name housenumber  \
# 0     30A Kallang Place, Singapore 339213, Singapore          NaN         30A
# 1                      Bengaluru - 560102, KA, India          NaN         NaN
# 2       33 Ubi Avenue 3, Singapore 408868, Singapore          NaN          33
# 3  Who Maid It, 539 West Commerce Street, Dallas,...  Who Maid It         539
# 4                               Montreal, QC, Canada          NaN         NaN
#
#                  street  postcode district state_code  ...  \
# 0         Kallang Place  339213.0  Central        NaN  ...
# 1                   NaN  560102.0      NaN         KA  ...
# 2          Ubi Avenue 3  408868.0  Central        NaN  ...
# 3  West Commerce Street   75208.0      NaN         TX  ...
# 4                   NaN       NaN      NaN         QC  ...
#
#                             county      state        country country_code  \
# 0                        Singapore  Singapore      Singapore           sg
# 1                        Bangalore  Karnataka          India           in
# 2                        Singapore  Singapore      Singapore           sg
# 3                    Dallas County      Texas  United States           us
# 4  Urban agglomeration of Montreal     Quebec         Canada           ca
#
#   confidence confidence_city_level  confidence_street_level  \
# 0   0.675000                  1.00                    0.675
# 1   1.000000                  1.00                      NaN
# 2   0.007396                  0.95                    0.950
# 3   1.000000                  1.00                    1.000
# 4   0.250000                  1.00                      NaN
#
#                     attribution    attribution_license  \
# 0  © OpenStreetMap contributors  Open Database License
# 1                           NaN              CC BY 4.0
# 2  © OpenStreetMap contributors  Open Database License
# 3  © OpenStreetMap contributors  Open Database License
# 4  © OpenStreetMap contributors  Open Database License
#
#                            attribution_url
# 0  https://www.openstreetmap.org/copyright
# 1    https://www.geonames.org/datasources/
# 2  https://www.openstreetmap.org/copyright
# 3  https://www.openstreetmap.org/copyright
# 4  https://www.openstreetmap.org/copyright
#
# [5 rows x 22 columns]

# %%
results_denied = results_denied.reset_index(drop=True)
results_denied
# Out:
#         Organization Name formatted_address  latitude  longitude  \
# 0         Diebold Nixdorf               NaN       NaN        NaN
# 1  KoiReader Technologies               NaN       NaN        NaN
# 2  KoiReader Technologies               NaN       NaN        NaN
# 3  KoiReader Technologies               NaN       NaN        NaN
# 4       Longbow Advantage               NaN       NaN        NaN
#
#             status                                           Address
# 0   REQUEST_DENIED        30A Kallang Place #04-01, Singapore 339213
# 1  INVALID_REQUEST  #153, Sector 5, HSR Layout, Bengaluru, KA 560102
# 2   REQUEST_DENIED            33 UBI Avenue 3, #08-13, Vertex 408868
# 3   REQUEST_DENIED       539 W. Commerce St. #1255, Dallas, TX 75208
# 4   REQUEST_DENIED  7250 Mile End Street #201, Montreal, QC, H2R 3A4

# %%
for i in range(requestdeniedgeocoded.shape[0]):
    requestdeniedgeocoded.given_address[i] = results_denied.Address[i]
    
requestdeniedgeocoded
# Out:
# C:\Users\seetc\AppData\Local\Temp/ipykernel_90236/895993128.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   requestdeniedgeocoded.given_address[i] = results_denied.Address[i]
#                                       given_address        lat         lon  \
# 0        30A Kallang Place #04-01, Singapore 339213   1.314741  103.865833
# 1  #153, Sector 5, HSR Layout, Bengaluru, KA 560102  12.971940   77.593690
# 2            33 UBI Avenue 3, #08-13, Vertex 408868   1.332978  103.894846
# 3       539 W. Commerce St. #1255, Dallas, TX 75208  32.773314  -96.833479
# 4  7250 Mile End Street #201, Montreal, QC, H2R 3A4  45.503182  -73.569806
#
#                                            formatted         name housenumber  \
# 0     30A Kallang Place, Singapore 339213, Singapore          NaN         30A
# 1                      Bengaluru - 560102, KA, India          NaN         NaN
# 2       33 Ubi Avenue 3, Singapore 408868, Singapore          NaN          33
# 3  Who Maid It, 539 West Commerce Street, Dallas,...  Who Maid It         539
# 4                               Montreal, QC, Canada          NaN         NaN
#
#                  street  postcode district state_code  ...  \
# 0         Kallang Place  339213.0  Central        NaN  ...
# 1                   NaN  560102.0      NaN         KA  ...
# 2          Ubi Avenue 3  408868.0  Central        NaN  ...
# 3  West Commerce Street   75208.0      NaN         TX  ...
# 4                   NaN       NaN      NaN         QC  ...
#
#                             county      state        country country_code  \
# 0                        Singapore  Singapore      Singapore           sg
# 1                        Bangalore  Karnataka          India           in
# 2                        Singapore  Singapore      Singapore           sg
# 3                    Dallas County      Texas  United States           us
# 4  Urban agglomeration of Montreal     Quebec         Canada           ca
#
#   confidence confidence_city_level  confidence_street_level  \
# 0   0.675000                  1.00                    0.675
# 1   1.000000                  1.00                      NaN
# 2   0.007396                  0.95                    0.950
# 3   1.000000                  1.00                    1.000
# 4   0.250000                  1.00                      NaN
#
#                     attribution    attribution_license  \
# 0  © OpenStreetMap contributors  Open Database License
# 1                           NaN              CC BY 4.0
# 2  © OpenStreetMap contributors  Open Database License
# 3  © OpenStreetMap contributors  Open Database License
# 4  © OpenStreetMap contributors  Open Database License
#
#                            attribution_url
# 0  https://www.openstreetmap.org/copyright
# 1    https://www.geonames.org/datasources/
# 2  https://www.openstreetmap.org/copyright
# 3  https://www.openstreetmap.org/copyright
# 4  https://www.openstreetmap.org/copyright
#
# [5 rows x 22 columns]

# %%
requestdeniedgeocoded.dropna(subset=['lat'], inplace=True)
requestdeniedgeocoded
# Out:
#                                       given_address        lat         lon  \
# 0        30A Kallang Place #04-01, Singapore 339213   1.314741  103.865833
# 1  #153, Sector 5, HSR Layout, Bengaluru, KA 560102  12.971940   77.593690
# 2            33 UBI Avenue 3, #08-13, Vertex 408868   1.332978  103.894846
# 3       539 W. Commerce St. #1255, Dallas, TX 75208  32.773314  -96.833479
# 4  7250 Mile End Street #201, Montreal, QC, H2R 3A4  45.503182  -73.569806
#
#                                            formatted         name housenumber  \
# 0     30A Kallang Place, Singapore 339213, Singapore          NaN         30A
# 1                      Bengaluru - 560102, KA, India          NaN         NaN
# 2       33 Ubi Avenue 3, Singapore 408868, Singapore          NaN          33
# 3  Who Maid It, 539 West Commerce Street, Dallas,...  Who Maid It         539
# 4                               Montreal, QC, Canada          NaN         NaN
#
#                  street  postcode district state_code  ...  \
# 0         Kallang Place  339213.0  Central        NaN  ...
# 1                   NaN  560102.0      NaN         KA  ...
# 2          Ubi Avenue 3  408868.0  Central        NaN  ...
# 3  West Commerce Street   75208.0      NaN         TX  ...
# 4                   NaN       NaN      NaN         QC  ...
#
#                             county      state        country country_code  \
# 0                        Singapore  Singapore      Singapore           sg
# 1                        Bangalore  Karnataka          India           in
# 2                        Singapore  Singapore      Singapore           sg
# 3                    Dallas County      Texas  United States           us
# 4  Urban agglomeration of Montreal     Quebec         Canada           ca
#
#   confidence confidence_city_level  confidence_street_level  \
# 0   0.675000                  1.00                    0.675
# 1   1.000000                  1.00                      NaN
# 2   0.007396                  0.95                    0.950
# 3   1.000000                  1.00                    1.000
# 4   0.250000                  1.00                      NaN
#
#                     attribution    attribution_license  \
# 0  © OpenStreetMap contributors  Open Database License
# 1                           NaN              CC BY 4.0
# 2  © OpenStreetMap contributors  Open Database License
# 3  © OpenStreetMap contributors  Open Database License
# 4  © OpenStreetMap contributors  Open Database License
#
#                            attribution_url
# 0  https://www.openstreetmap.org/copyright
# 1    https://www.geonames.org/datasources/
# 2  https://www.openstreetmap.org/copyright
# 3  https://www.openstreetmap.org/copyright
# 4  https://www.openstreetmap.org/copyright
#
# [5 rows x 22 columns]

# %%
requestdeniedgeocoded = requestdeniedgeocoded.reset_index(drop=True)
requestdeniedgeocoded
# Out:
#                                       given_address        lat         lon  \
# 0        30A Kallang Place #04-01, Singapore 339213   1.314741  103.865833
# 1  #153, Sector 5, HSR Layout, Bengaluru, KA 560102  12.971940   77.593690
# 2            33 UBI Avenue 3, #08-13, Vertex 408868   1.332978  103.894846
# 3       539 W. Commerce St. #1255, Dallas, TX 75208  32.773314  -96.833479
# 4  7250 Mile End Street #201, Montreal, QC, H2R 3A4  45.503182  -73.569806
#
#                                            formatted         name housenumber  \
# 0     30A Kallang Place, Singapore 339213, Singapore          NaN         30A
# 1                      Bengaluru - 560102, KA, India          NaN         NaN
# 2       33 Ubi Avenue 3, Singapore 408868, Singapore          NaN          33
# 3  Who Maid It, 539 West Commerce Street, Dallas,...  Who Maid It         539
# 4                               Montreal, QC, Canada          NaN         NaN
#
#                  street  postcode district state_code  ...  \
# 0         Kallang Place  339213.0  Central        NaN  ...
# 1                   NaN  560102.0      NaN         KA  ...
# 2          Ubi Avenue 3  408868.0  Central        NaN  ...
# 3  West Commerce Street   75208.0      NaN         TX  ...
# 4                   NaN       NaN      NaN         QC  ...
#
#                             county      state        country country_code  \
# 0                        Singapore  Singapore      Singapore           sg
# 1                        Bangalore  Karnataka          India           in
# 2                        Singapore  Singapore      Singapore           sg
# 3                    Dallas County      Texas  United States           us
# 4  Urban agglomeration of Montreal     Quebec         Canada           ca
#
#   confidence confidence_city_level  confidence_street_level  \
# 0   0.675000                  1.00                    0.675
# 1   1.000000                  1.00                      NaN
# 2   0.007396                  0.95                    0.950
# 3   1.000000                  1.00                    1.000
# 4   0.250000                  1.00                      NaN
#
#                     attribution    attribution_license  \
# 0  © OpenStreetMap contributors  Open Database License
# 1                           NaN              CC BY 4.0
# 2  © OpenStreetMap contributors  Open Database License
# 3  © OpenStreetMap contributors  Open Database License
# 4  © OpenStreetMap contributors  Open Database License
#
#                            attribution_url
# 0  https://www.openstreetmap.org/copyright
# 1    https://www.geonames.org/datasources/
# 2  https://www.openstreetmap.org/copyright
# 3  https://www.openstreetmap.org/copyright
# 4  https://www.openstreetmap.org/copyright
#
# [5 rows x 22 columns]

# %%
cleaned_results = merged_inner[ ['Organization Name', 'formatted_address', 'latitude', 'longitude', 'status' , 'Address'] ]
cleaned_results
# Out:
#            Organization Name  \
# 0             Leaf Logistics
# 1                     Shippo
# 2                    Nexxiot
# 3                    Nexxiot
# 4                    Nexxiot
# ..                       ...
# 242          Dayton T. Brown
# 243        Idle Free Systems
# 244                 Hi-G-Tek
# 245                 Hi-G-Tek
# 246  CellWand Communications
#
#                                      formatted_address   latitude   longitude  \
# 0         305 W Broadway #147, New York, NY 10013, USA  40.721500  -74.004274
# 1     731 Market St #200, San Francisco, CA 94103, USA  37.786791 -122.404049
# 2            Hardstrasse 201, 8005 Zürich, Switzerland  47.386189    8.517259
# 3    Marktstraße 32-34, 65428 Rüsselsheim am Main, ...  49.992549    8.412541
# 4    7290 Virginia Pkwy STE 3000, McKinney, TX 7507...  33.200849  -96.712359
# ..                                                 ...        ...         ...
# 242                             Shelton, CT 06484, USA  41.316486  -73.093164
# 243      7617 Mineral Point Rd, Madison, WI 53717, USA  43.060161  -89.514922
# 244           7519 Standish Pl, Derwood, MD 20855, USA  39.109215  -77.154179
# 245              Ha-Kharoshet St 16, Or Yehuda, Israel  32.021134   34.862667
# 246     48 Yonge St #1200, Toronto, ON M5E 1G6, Canada  43.647992  -79.377735
#
#     status                                            Address
# 0       OK   305 West Broadway Suite 147,  New York, NY 10013
# 1       OK  731 Market Street, 200, San Francisco, Califor...
# 2       OK  Prime Tower, Hardstrasse 201, 8005 Zürich, Swi...
# 3       OK  Marktstrasse 32 – 34, 65428 Rüsselsheim am Mai...
# 4       OK  7290 Virginia Parkway Suite 3000, McKinney, TX...
# ..     ...                                                ...
# 242     OK                      Shelton, 06484, United States
# 243     OK     7617 Mineral Point Road, Madison, WI 53717, US
# 244     OK  7519 Standish Pl, Rockville, MD 20855, United ...
# 245     OK         Ha-Kharoshet 16, Or Yehuda, IL 6037584, IL
# 246     OK  48 Yonge Street, Suite 1200, Toronto, Ontario ...
#
# [247 rows x 6 columns]

# %%
for i in range(requestdeniedgeocoded.shape[0]):
    print(i)
    cleaned_results.loc[ cleaned_results.Address == requestdeniedgeocoded.given_address[i], "latitude"] = requestdeniedgeocoded.lat[i]
    cleaned_results.loc[ cleaned_results.Address == requestdeniedgeocoded.given_address[i], "longitude"] = requestdeniedgeocoded.lon[i]

finalresults = cleaned_results
finalresults = finalresults[ (finalresults['status'] == "REQUEST_DENIED") | (finalresults['status'] == "ZERO_RESULTS") | (finalresults['status'] == "INVALID_REQUEST") ]
finalresults
# Out:
# 0
# 1
# 2
# 3
# 4
# C:\Users\seetc\anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#           Organization Name formatted_address   latitude   longitude  \
# 56          Diebold Nixdorf               NaN   1.314741  103.865833
# 175  KoiReader Technologies               NaN  12.971940   77.593690
# 176  KoiReader Technologies               NaN   1.332978  103.894846
# 177  KoiReader Technologies               NaN  32.773314  -96.833479
# 193       Longbow Advantage               NaN  45.503182  -73.569806
#
#               status                                           Address
# 56    REQUEST_DENIED        30A Kallang Place #04-01, Singapore 339213
# 175  INVALID_REQUEST  #153, Sector 5, HSR Layout, Bengaluru, KA 560102
# 176   REQUEST_DENIED            33 UBI Avenue 3, #08-13, Vertex 408868
# 177   REQUEST_DENIED       539 W. Commerce St. #1255, Dallas, TX 75208
# 193   REQUEST_DENIED  7250 Mile End Street #201, Montreal, QC, H2R 3A4

# %%
cleaned_results.dropna(subset=['latitude'], inplace=True)
cleaned_results
# Out:
# C:\Users\seetc\anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#            Organization Name  \
# 0             Leaf Logistics
# 1                     Shippo
# 2                    Nexxiot
# 3                    Nexxiot
# 4                    Nexxiot
# ..                       ...
# 242          Dayton T. Brown
# 243        Idle Free Systems
# 244                 Hi-G-Tek
# 245                 Hi-G-Tek
# 246  CellWand Communications
#
#                                      formatted_address   latitude   longitude  \
# 0         305 W Broadway #147, New York, NY 10013, USA  40.721500  -74.004274
# 1     731 Market St #200, San Francisco, CA 94103, USA  37.786791 -122.404049
# 2            Hardstrasse 201, 8005 Zürich, Switzerland  47.386189    8.517259
# 3    Marktstraße 32-34, 65428 Rüsselsheim am Main, ...  49.992549    8.412541
# 4    7290 Virginia Pkwy STE 3000, McKinney, TX 7507...  33.200849  -96.712359
# ..                                                 ...        ...         ...
# 242                             Shelton, CT 06484, USA  41.316486  -73.093164
# 243      7617 Mineral Point Rd, Madison, WI 53717, USA  43.060161  -89.514922
# 244           7519 Standish Pl, Derwood, MD 20855, USA  39.109215  -77.154179
# 245              Ha-Kharoshet St 16, Or Yehuda, Israel  32.021134   34.862667
# 246     48 Yonge St #1200, Toronto, ON M5E 1G6, Canada  43.647992  -79.377735
#
#     status                                            Address
# 0       OK   305 West Broadway Suite 147,  New York, NY 10013
# 1       OK  731 Market Street, 200, San Francisco, Califor...
# 2       OK  Prime Tower, Hardstrasse 201, 8005 Zürich, Swi...
# 3       OK  Marktstrasse 32 – 34, 65428 Rüsselsheim am Mai...
# 4       OK  7290 Virginia Parkway Suite 3000, McKinney, TX...
# ..     ...                                                ...
# 242     OK                      Shelton, 06484, United States
# 243     OK     7617 Mineral Point Road, Madison, WI 53717, US
# 244     OK  7519 Standish Pl, Rockville, MD 20855, United ...
# 245     OK         Ha-Kharoshet 16, Or Yehuda, IL 6037584, IL
# 246     OK  48 Yonge Street, Suite 1200, Toronto, Ontario ...
#
# [247 rows x 6 columns]

# %%
cleaned_results.isnull().any()
# Out:
# Organization Name    False
# formatted_address     True
# latitude             False
# longitude            False
# status               False
# Address              False
# dtype: bool

# %%
cleaned_results.reset_index(drop=True)
cleaned_results = cleaned_results[ ['Organization Name', 'latitude', 'longitude'] ]
cleaned_results
# Out:
#            Organization Name   latitude   longitude
# 0             Leaf Logistics  40.721500  -74.004274
# 1                     Shippo  37.786791 -122.404049
# 2                    Nexxiot  47.386189    8.517259
# 3                    Nexxiot  49.992549    8.412541
# 4                    Nexxiot  33.200849  -96.712359
# ..                       ...        ...         ...
# 242          Dayton T. Brown  41.316486  -73.093164
# 243        Idle Free Systems  43.060161  -89.514922
# 244                 Hi-G-Tek  39.109215  -77.154179
# 245                 Hi-G-Tek  32.021134   34.862667
# 246  CellWand Communications  43.647992  -79.377735
#
# [247 rows x 3 columns]

# %%
pd.DataFrame(cleaned_results).to_csv('resultslatlon.csv', encoding='utf8')
