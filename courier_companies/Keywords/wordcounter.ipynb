# %%
#combine files 
import glob 
import os
#clean 
import string
import pandas as pd
import numpy as np
import emoji
import nltk
import re 
from cleantext import clean
#sleep timer 
import time 
import logging
import threading
#show most common words
from collections import Counter
#word cloud 
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('ninjavan_thailand.csv')
df = df.dropna()

column_titles = ['rating','caption']
df1 = df.reindex(columns=column_titles)
df1
# Out:
#      rating                                            caption
# 0       5.0  (Translated by Google) Thank you very much  (O...
# 2       1.0  Always wrong delivery!!!  How do you even trai...
# 3       1.0  (Translated by Google) The delivery man is ver...
# 4       1.0  (Translated by Google) Please call the recipie...
# 5       5.0  (Translated by Google) I don't know what other...
# ..      ...                                                ...
# 922     1.0  (Translated by Google) Terrible staff Delivery...
# 923     3.0  (Translated by Google) Wait until the product ...
# 925     5.0  (Translated by Google) Good. Fast delivery. St...
# 928     5.0  (Translated by Google) Fast delivery and knowi...
# 929     5.0  (Translated by Google) The staff speak good, h...
#
# [499 rows x 2 columns]

# %%
df1['middle'] = df1['caption'].str.split(")").str[1] 
df1['Reviews'] = df1['middle'].str.split("(").str[0]

df1 = df1.reset_index()

# %%
df1['Reviews'].fillna('0', inplace = True)
for i, row in df1.iterrows(): 
    review = row['Reviews']
    if review == '0':
        df1['Reviews'][i] = review.replace('0', row['caption'])
df1
# Out:
# C:\Users\seetc\AppData\Local\Temp/ipykernel_99756/4092710684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Reviews'][i] = review.replace('0', row['caption'])
#      index  rating                                            caption  \
# 0        0     5.0  (Translated by Google) Thank you very much  (O...
# 1        2     1.0  Always wrong delivery!!!  How do you even trai...
# 2        3     1.0  (Translated by Google) The delivery man is ver...
# 3        4     1.0  (Translated by Google) Please call the recipie...
# 4        5     5.0  (Translated by Google) I don't know what other...
# ..     ...     ...                                                ...
# 494    922     1.0  (Translated by Google) Terrible staff Delivery...
# 495    923     3.0  (Translated by Google) Wait until the product ...
# 496    925     5.0  (Translated by Google) Good. Fast delivery. St...
# 497    928     5.0  (Translated by Google) Fast delivery and knowi...
# 498    929     5.0  (Translated by Google) The staff speak good, h...
#
#                                                 middle  \
# 0                       Thank you very much  (Original
# 1                                                  NaN
# 2     The delivery man is very bad. It's the worst ...
# 3     Please call the recipient and send it to the ...
# 4     I don't know what other people's are, but min...
# ..                                                 ...
# 494   Terrible staff Delivery of the front of the h...
# 495   Wait until the product has been designated da...
# 496   Good. Fast delivery. Staff speak politely.  (...
# 497   Fast delivery and knowing the route. Reliable...
# 498   The staff speak good, have good manners.  (Or...
#
#                                                Reviews
# 0                                Thank you very much
# 1    Always wrong delivery!!!  How do you even trai...
# 2     The delivery man is very bad. It's the worst ...
# 3     Please call the recipient and send it to the ...
# 4     I don't know what other people's are, but min...
# ..                                                 ...
# 494   Terrible staff Delivery of the front of the h...
# 495   Wait until the product has been designated da...
# 496       Good. Fast delivery. Staff speak politely.
# 497   Fast delivery and knowing the route. Reliable.
# 498         The staff speak good, have good manners.
#
# [499 rows x 5 columns]

# %% [markdown]
# ### Clean the data

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')

def clean_text_round1(text):
    '''Make text lowercase, remove punctuation, remove words containing numbers and lemmatize/stem.'''
    text = str(text).lower()
    text = re.sub('#\w*', '', text)
    text = re.sub('@\w*', '', text)    
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = clean(text, no_emoji=True)
    text = emoji.demojize(text, delimiters=("", "")) #change emoji into text 
    text = ' '.join([word for word in text.split() if word not in (stop)])
    return text

# Let's take a look at the updated text
df1['Reviews_processed'] = pd.DataFrame(df1['Reviews'].apply(clean_text_round1))
df1
# Out:
#      index  rating                                            caption  \
# 0        0     5.0  (Translated by Google) Thank you very much  (O...
# 1        2     1.0  Always wrong delivery!!!  How do you even trai...
# 2        3     1.0  (Translated by Google) The delivery man is ver...
# 3        4     1.0  (Translated by Google) Please call the recipie...
# 4        5     5.0  (Translated by Google) I don't know what other...
# ..     ...     ...                                                ...
# 494    922     1.0  (Translated by Google) Terrible staff Delivery...
# 495    923     3.0  (Translated by Google) Wait until the product ...
# 496    925     5.0  (Translated by Google) Good. Fast delivery. St...
# 497    928     5.0  (Translated by Google) Fast delivery and knowi...
# 498    929     5.0  (Translated by Google) The staff speak good, h...
#
#                                                 middle  \
# 0                       Thank you very much  (Original
# 1                                                  NaN
# 2     The delivery man is very bad. It's the worst ...
# 3     Please call the recipient and send it to the ...
# 4     I don't know what other people's are, but min...
# ..                                                 ...
# 494   Terrible staff Delivery of the front of the h...
# 495   Wait until the product has been designated da...
# 496   Good. Fast delivery. Staff speak politely.  (...
# 497   Fast delivery and knowing the route. Reliable...
# 498   The staff speak good, have good manners.  (Or...
#
#                                                Reviews  \
# 0                                Thank you very much
# 1    Always wrong delivery!!!  How do you even trai...
# 2     The delivery man is very bad. It's the worst ...
# 3     Please call the recipient and send it to the ...
# 4     I don't know what other people's are, but min...
# ..                                                 ...
# 494   Terrible staff Delivery of the front of the h...
# 495   Wait until the product has been designated da...
# 496       Good. Fast delivery. Staff speak politely.
# 497   Fast delivery and knowing the route. Reliable.
# 498         The staff speak good, have good manners.
#
#                                      Reviews_processed
# 0                                           thank much
# 1    always wrong delivery even train staff could e...
# 2                     delivery man bad worst transport
# 3       please call recipient send recipients hand ...
# 4    dont know peoples mine day received items fast...
# ..                                                 ...
# 494  terrible staff delivery front house need wait ...
# 495  wait product designated date come pass transpo...
# 496            good fast delivery staff speak politely
# 497               fast delivery knowing route reliable
# 498                      staff speak good good manners
#
# [499 rows x 6 columns]

# %% [markdown]
# ### Sentiment analysis

# %%
from nltk.stem import WordNetLemmatizer 
lemmatizer = WordNetLemmatizer()
def clean_text_round2(text):
    word_list = nltk.word_tokenize(text)
    lemmatized_output = ' '.join([lemmatizer.lemmatize(w) for w in word_list])
    return lemmatized_output
df1['Reviews_processed2'] = pd.DataFrame(df1['Reviews_processed'].apply(clean_text_round2))

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

def sentiment_scores(sentence):
    sid_obj = SentimentIntensityAnalyzer() 
    sentiment_dict = sid_obj.polarity_scores(sentence) 
    if sentiment_dict['compound'] >= 0.05 : 
       return "Positive"
    elif sentiment_dict['compound'] <= - 0.05 : 
        return "Negative"
    else : 
       return "Neutral"
        
df1['Sentiment'] = pd.DataFrame(df1['Reviews_processed2'].apply(sentiment_scores))

# %%
column_titles = ['rating','Reviews','Sentiment']
df2 = df1.reindex(columns=column_titles)
df2
# Out:
#      rating                                            Reviews Sentiment
# 0       5.0                              Thank you very much    Positive
# 1       1.0  Always wrong delivery!!!  How do you even trai...  Negative
# 2       1.0   The delivery man is very bad. It's the worst ...  Negative
# 3       1.0   Please call the recipient and send it to the ...  Positive
# 4       5.0   I don't know what other people's are, but min...   Neutral
# ..      ...                                                ...       ...
# 494     1.0   Terrible staff Delivery of the front of the h...  Negative
# 495     3.0   Wait until the product has been designated da...   Neutral
# 496     5.0       Good. Fast delivery. Staff speak politely.    Positive
# 497     5.0   Fast delivery and knowing the route. Reliable.     Neutral
# 498     5.0         The staff speak good, have good manners.    Positive
#
# [499 rows x 3 columns]

# %%
df2.to_csv('ninja_th_reviews.csv')

# %%
df_neg = df1.drop(df1[df1['Sentiment'] != 'Negative'].index)
df_neg
# Out:
#      index  rating                                            caption  \
# 1        2     1.0  Always wrong delivery!!!  How do you even trai...
# 2        3     1.0  (Translated by Google) The delivery man is ver...
# 6        7     1.0  (Translated by Google) At first the app said i...
# 10      12     1.0  Worst company I have dealt with.  delay in del...
# 11      13     1.0  (Translated by Google) .2 This item is from an...
# ..     ...     ...                                                ...
# 455    836     5.0  (Translated by Google) Fast delivery. Product ...
# 459    844     1.0  (Translated by Google) The delivery was very s...
# 471    870     2.0  (Translated by Google) Slow delivery. Take you...
# 486    905     5.0  (Translated by Google) The staff speaks very w...
# 494    922     1.0  (Translated by Google) Terrible staff Delivery...
#
#                                                 middle  \
# 1                                                  NaN
# 2     The delivery man is very bad. It's the worst ...
# 6     At first the app said it was shipping. Call t...
# 10                                                 NaN
# 11    .2 This item is from another seller...just th...
# ..                                                 ...
# 455   Fast delivery. Product is not damaged.  (Orig...
# 459   The delivery was very slow and the item retur...
# 471   Slow delivery. Take your convenience. Postpon...
# 486   The staff speaks very well. The delivery is f...
# 494   Terrible staff Delivery of the front of the h...
#
#                                                Reviews  \
# 1    Always wrong delivery!!!  How do you even trai...
# 2     The delivery man is very bad. It's the worst ...
# 6     At first the app said it was shipping. Call t...
# 10   Worst company I have dealt with.  delay in del...
# 11    .2 This item is from another seller...just th...
# ..                                                 ...
# 455           Fast delivery. Product is not damaged.
# 459   The delivery was very slow and the item retur...
# 471   Slow delivery. Take your convenience. Postpon...
# 486   The staff speaks very well. The delivery is f...
# 494   Terrible staff Delivery of the front of the h...
#
#                                      Reviews_processed  \
# 1    always wrong delivery even train staff could e...
# 2                     delivery man bad worst transport
# 6    first app said shipping call center ask tell w...
# 10   worst company dealt delay delivery difficulty ...
# 11   item another sellerjust wrong postcodebut deli...
# ..                                                 ...
# 455                      fast delivery product damaged
# 459  delivery slow item returned claiming address c...
# 471  slow delivery take convenience postpone delive...
# 486         staff speaks well delivery fast damage ...
# 494  terrible staff delivery front house need wait ...
#
#                                     Reviews_processed2 Sentiment
# 1    always wrong delivery even train staff could e...  Negative
# 2                     delivery man bad worst transport  Negative
# 6    first app said shipping call center ask tell w...  Negative
# 10   worst company dealt delay delivery difficulty ...  Negative
# 11   item another sellerjust wrong postcodebut deli...  Negative
# ..                                                 ...       ...
# 455                      fast delivery product damaged  Negative
# 459  delivery slow item returned claiming address c...  Negative
# 471  slow delivery take convenience postpone delive...  Negative
# 486         staff speaks well delivery fast damage ...  Negative
# 494  terrible staff delivery front house need wait ...  Negative
#
# [113 rows x 8 columns]

# %%
#combining the text into one long string for word cloud 
cloud_string = df_neg['Reviews_processed2'].str.cat(sep=' ')

# %%
# Let's first pull out the top 30 words for each category
words = []
for word in cloud_string.split():
        words.append(word)
Counter(words).most_common()
# Out:
# [('...', 93),
#  ('delivery', 55),
#  ('bad', 45),
#  ('day', 33),
#  ('item', 29),
#  ('time', 28),
#  ('call', 28),
#  ('service', 21),
#  ('delivered', 19),
#  ('cant', 17),
#  ('tell', 16),
#  ('slow', 16),
#  ('send', 15),
#  ('contact', 15),
#  ('company', 14),
#  ('one', 14),
#  ('deliver', 13),
#  ('didnt', 13),
#  ('come', 13),
#  ('wait', 13),
#  ('good', 13),
#  ('product', 13),
#  ('staff', 12),
#  ('worst', 12),
#  ('transport', 12),
#  ('said', 12),
#  ('customer', 12),
#  ('waiting', 12),
#  ('dont', 12),
#  ('received', 12),
#  ('sent', 12),
#  ('called', 11),
#  ('yet', 11),
#  ('say', 10),
#  ('number', 10),
#  ('recipient', 10),
#  ('system', 10),
#  ('house', 10),
#  ('even', 9),
#  ('first', 9),
#  ('back', 9),
#  ('u', 9),
#  ('order', 9),
#  ('still', 9),
#  ('contacted', 9),
#  ('ninja', 9),
#  ('ordered', 9),
#  ('terrible', 9),
#  ('wrong', 8),
#  ('address', 8),
#  ('today', 8),
#  ('shop', 8),
#  ('poor', 8),
#  ('arrived', 8),
#  ('van', 8),
#  ('fast', 8),
#  ('employee', 8),
#  ('receive', 7),
#  ('status', 7),
#  ('thing', 7),
#  ('broken', 7),
#  ('next', 7),
#  ('really', 7),
#  ('calling', 7),
#  ('parcel', 6),
#  ('sender', 6),
#  ('havent', 6),
#  ('inform', 6),
#  ('postpone', 6),
#  ('unable', 6),
#  ('pick', 6),
#  ('front', 6),
#  ('never', 6),
#  ('package', 6),
#  ('date', 6),
#  ('always', 5),
#  ('every', 5),
#  ('shipping', 5),
#  ('branch', 5),
#  ('problem', 5),
#  ('week', 5),
#  ('transportation', 5),
#  ('ordering', 5),
#  ('know', 5),
#  ('home', 5),
#  ('shopee', 5),
#  ('confused', 5),
#  ('star', 5),
#  ('could', 4),
#  ('worker', 4),
#  ('ask', 4),
#  ('another', 4),
#  ('came', 4),
#  ('claiming', 4),
#  ('check', 4),
#  ('get', 4),
#  ('sending', 4),
#  ('box', 4),
#  ('since', 4),
#  ('many', 4),
#  ('appointment', 4),
#  ('use', 4),
#  ('responsibility', 4),
#  ('responsible', 4),
#  ('arrive', 4),
#  ('though', 4),
#  ('got', 4),
#  ('take', 4),
#  ('person', 4),
#  ('late', 4),
#  ('oclock', 4),
#  ('therefore', 4),
#  ('train', 3),
#  ('center', 3),
#  ('leave', 3),
#  ('stuff', 3),
#  ('phone', 3),
#  ('im', 3),
#  ('round', 3),
#  ('long', 3),
#  ('like', 3),
#  ('management', 3),
#  ('per', 3),
#  ('suck', 3),
#  ('pickled', 3),
#  ('using', 3),
#  ('bangkok', 3),
#  ('would', 3),
#  ('told', 3),
#  ('follow', 3),
#  ('returned', 3),
#  ('pm', 3),
#  ('may', 3),
#  ('office', 3),
#  ('turn', 3),
#  ('within', 3),
#  ('can', 3),
#  ('not', 3),
#  ('change', 3),
#  ('right', 3),
#  ('well', 3),
#  ('samut', 3),
#  ('talk', 3),
#  ('stuck', 3),
#  ('immediately', 3),
#  ('please', 2),
#  ('man', 2),
#  ('delay', 2),
#  ('bounced', 2),
#  ('second', 2),
#  ('else', 2),
#  ('hurry', 2),
#  ('rama', 2),
#  ('online', 2),
#  ('car', 2),
#  ('tired', 2),
#  ('piece', 2),
#  ('stop', 2),
#  ('reason', 2),
#  ('way', 2),
#  ('able', 2),
#  ('enough', 2),
#  ('due', 2),
#  ('ive', 2),
#  ('notification', 2),
#  ('lost', 2),
#  ('ever', 2),
#  ('different', 2),
#  ('quickly', 2),
#  ('advance', 2),
#  ('lot', 2),
#  ('find', 2),
#  ('let', 2),
#  ('delayed', 2),
#  ('pressed', 2),
#  ('refused', 2),
#  ('hasnt', 2),
#  ('store', 2),
#  ('child', 2),
#  ('blame', 2),
#  ('throughout', 2),
#  ('three', 2),
#  ('go', 2),
#  ('claimed', 2),
#  ('want', 2),
#  ('give', 2),
#  ('think', 2),
#  ('waited', 2),
#  ('thung', 2),
#  ('khru', 2),
#  ('went', 2),
#  ('residence', 2),
#  ('going', 2),
#  ('awful', 2),
#  ('intersection', 2),
#  ('separate', 2),
#  ('april', 2),
#  ('avoided', 2),
#  ('people', 2),
#  ('prakan', 2),
#  ('used', 2),
#  ('tomorrow', 2),
#  ('something', 2),
#  ('province', 2),
#  ('hour', 2),
#  ('despite', 2),
#  ('damage', 2),
#  ('coming', 2),
#  ('place', 2),
#  ('put', 2),
#  ('condition', 2),
#  ('possible', 2),
#  ('room', 2),
#  ('quick', 2),
#  ('notify', 2),
#  ('politely', 2),
#  ('afternoon', 2),
#  ('app', 1),
#  ('warehouse', 1),
#  ('minute', 1),
#  ('passed', 1),
#  ('failed', 1),
#  ('allow', 1),
#  ('dealt', 1),
#  ('difficulty', 1),
#  ('communicating', 1),
#  ('support', 1),
#  ('sellerjust', 1),
#  ('postcodebut', 1),
#  ('toninjai', 1),
#  ('reach', 1),
#  ('hand', 1),
#  ('thomas', 1),
#  ('someone', 1),
#  ('master', 1),
#  ('sign', 1),
#  ('keep', 1),
#  ('encountered', 1),
#  ('failing', 1),
#  ('understand', 1),
#  ('fail', 1),
#  ('hit', 1),
#  ('word', 1),
#  ('scheduled', 1),
#  ('baht', 1),
#  ('holiday', 1),
#  ('telling', 1),
#  ('mail', 1),
#  ('telegram', 1),
#  ('carry', 1),
#  ('movement', 1),
#  ('nothing', 1),
#  ('help', 1),
#  ('recommend', 1),
#  ('waste', 1),
#  ('name', 1),
#  ('appropriate', 1),
#  ('changing', 1),
#  ('logistic', 1),
#  ('turtle', 1),
#  ('latest', 1),
#  ('unpacked', 1),
#  ('looked', 1),
#  ('exactly', 1),
#  ('see', 1),
#  ('ninj', 1),
#  ('kabinburi', 1),
#  ('unsuccessful', 1),
#  ('requesting', 1),
#  ('adjust', 1),
#  ('ineffective', 1),
#  ('irresponsible', 1),
#  ('left', 1),
#  ('necessary', 1),
#  ('missing', 1),
#  ('relayed', 1),
#  ('coordination', 1),
#  ('part', 1),
#  ('postponement', 1),
#  ('basis', 1),
#  ('ruined', 1),
#  ('soon', 1),
#  ('ill', 1),
#  ('cancellation', 1),
#  ('return', 1),
#  ('night', 1),
#  ('logistics', 1),
#  ('seen', 1),
#  ('according', 1),
#  ('provider', 1),
#  ('wasnt', 1),
#  ('daughter', 1),
#  ('lived', 1),
#  ('money', 1),
#  ('make', 1),
#  ('thought', 1),
#  ('wouldnt', 1),
#  ('anymore', 1),
#  ('saw', 1),
#  ('negative', 1),
#  ('review', 1),
#  ('button', 1),
#  ('informed', 1),
#  ('wasting', 1),
#  ('youre', 1),
#  ('discouraged', 1),
#  ('rate', 1),
#  ('suddenly', 1),
#  ('arrange', 1),
#  ('boring', 1),
#  ('far', 1),
#  ('straight', 1),
#  ('doesnt', 1),
#  ('fit', 1),
#  ('writes', 1),
#  ('around', 1),
#  ('um', 1),
#  ('k', 1),
#  ('bringing', 1),
#  ('picture', 1),
#  ('refuse', 1),
#  ('shouldnt', 1),
#  ('experience', 1),
#  ('crazy', 1),
#  ('complain', 1),
#  ('origin', 1),
#  ('rain', 1),
#  ('excuse', 1),
#  ('sleep', 1),
#  ('denied', 1),
#  ('much', 1),
#  ('increasingly', 1),
#  ('fear', 1),
#  ('bouncing', 1),
#  ('sat', 1),
#  ('end', 1),
#  ('honestly', 1),
#  ('close', 1),
#  ('eat', 1),
#  ('attached', 1),
#  ('receiver', 1),
#  ('ready', 1),
#  ('true', 1),
#  ('met', 1),
#  ('inseparable', 1),
#  ('slowest', 1),
#  ('whole', 1),
#  ('big', 1),
#  ('courier', 1),
#  ('speaking', 1),
#  ('liar', 1),
#  ('recommended', 1),
#  ('china', 1),
#  ('rajyuri', 1),
#  ('curse', 1),
#  ('morning', 1),
#  ('lunch', 1),
#  ('evening', 1),
#  ('horrible', 1),
#  ('without', 1),
#  ('live', 1),
#  ('seed', 1),
#  ('pay', 1),
#  ('express', 1),
#  ('thursday', 1),
#  ('tuesday', 1),
#  ('sakhon', 1),
#  ('near', 1),
#  ('dc', 1),
#  ('mar', 1),
#  ('earth', 1),
#  ('bang', 1),
#  ('pain', 1),
#  ('ayutthaya', 1),
#  ('couldnt', 1),
#  ('available', 1),
#  ('request', 1),
#  ('cancel', 1),
#  ('yesterday', 1),
#  ('deserving', 1),
#  ('later', 1),
#  ('kerry', 1),
#  ('flash', 1),
#  ('thinking', 1),
#  ('ok', 1),
#  ('quite', 1),
#  ('work', 1),
#  ('low', 1),
#  ('anything', 1),
#  ('nakhon', 1),
#  ('pathom', 1),
#  ('took', 1),
#  ('loca', 1),
#  ('specify', 1),
#  ('missed', 1),
#  ('added', 1),
#  ('false', 1),
#  ('state', 1),
#  ('segregation', 1),
#  ('transported', 1),
#  ('adjacent', 1),
#  ('appears', 1),
#  ('postal', 1),
#  ('lack', 1),
#  ('training', 1),
#  ('try', 1),
#  ('tracking', 1),
#  ('faked', 1),
#  ('complained', 1),
#  ('taken', 1),
#  ('account', 1),
#  ('shoot', 1),
#  ('residencewhat', 1),
#  ('reserve', 1),
#  ('notifying', 1),
#  ('manner', 1),
#  ('somehow', 1),
#  ('constant', 1),
#  ('juristic', 1),
#  ('asked', 1),
#  ('area', 1),
#  ('sell', 1),
#  ('mailbox', 1),
#  ('arent', 1),
#  ('understanding', 1),
#  ('soi', 1),
#  ('fang', 1),
#  ('odd', 1),
#  ('alone', 1),
#  ('signed', 1),
#  ('habit', 1),
#  ('inaccuracy', 1),
#  ('answer', 1),
#  ('hold', 1),
#  ('poorly', 1),
#  ('wrinkled', 1),
#  ('meal', 1),
#  ('must', 1),
#  ('perfect', 1),
#  ('essence', 1),
#  ('accident', 1),
#  ('happen', 1),
#  ('force', 1),
#  ('majeure', 1),
#  ('okay', 1),
#  ('woman', 1),
#  ('bicycle', 1),
#  ('basket', 1),
#  ('away', 1),
#  ('discomfort', 1),
#  ('walk', 1),
#  ('building', 1),
#  ('outside', 1),
#  ('business', 1),
#  ('normal', 1),
#  ('frantic', 1),
#  ('short', 1),
#  ('job', 1),
#  ('water', 1),
#  ('attentive', 1),
#  ('also', 1),
#  ('checking', 1),
#  ('encounter', 1),
#  ('polite', 1),
#  ('criticize', 1),
#  ('crumpled', 1),
#  ('speak', 1),
#  ('shoppi', 1),
#  ('reported', 1),
#  ('sooner', 1),
#  ('slightly', 1),
#  ('bothered', 1),
#  ('disappointed', 1),
#  ('monday', 1),
#  ('wednesday', 1),
#  ('worried', 1),
#  ('getting', 1),
#  ('slowly', 1),
#  ('normally', 1),
#  ('standard', 1),
#  ('carefully', 1),
#  ('payment', 1),
#  ('amount', 1),
#  ('familiar', 1),
#  ('pickle', 1),
#  ('last', 1),
#  ('mind', 1),
#  ('delivering', 1),
#  ('new', 1),
#  ('staying', 1),
#  ('better', 1),
#  ('cost', 1),
#  ('notified', 1),
#  ('baan', 1),
#  ('ua', 1),
#  ('floor', 1),
#  ('raised', 1),
#  ('argue', 1),
#  ('rise', 1),
#  ('everyone', 1),
#  ('thailand', 1),
#  ('bigger', 1),
#  ('singapore', 1),
#  ('country', 1),
#  ('owner', 1),
#  ('access', 1),
#  ('demand', 1),
#  ('thai', 1),
#  ('already', 1),
#  ('folded', 1),
#  ('sick', 1),
#  ('damaged', 1),
#  ('convenience', 1),
#  ('five', 1),
#  ('speaks', 1),
#  ('need', 1),
#  ('picked', 1),
#  ('running', 1),
#  ('hearing', 1),
#  ('buzzer', 1)]

# %%
allwords = Counter(words).most_common()
allWordsDf = pd.DataFrame(allwords, columns=['word', 'count'])
allWordsDf
# Out:
#          word  count
# 0         ...     93
# 1    delivery     55
# 2         bad     45
# 3         day     33
# 4        item     29
# ..        ...    ...
# 515      need      1
# 516    picked      1
# 517   running      1
# 518   hearing      1
# 519    buzzer      1
#
# [520 rows x 2 columns]

# %%
allWordsDf['clean1'] = pd.DataFrame(allWordsDf['word'].apply(clean_text_round1))
allWordsDf
# Out:
#          word  count    clean1
# 0         ...     93
# 1    delivery     55  delivery
# 2         bad     45       bad
# 3         day     33       day
# 4        item     29      item
# ..        ...    ...       ...
# 515      need      1      need
# 516    picked      1    picked
# 517   running      1   running
# 518   hearing      1   hearing
# 519    buzzer      1    buzzer
#
# [520 rows x 3 columns]

# %%
allWordsDf['clean2'] = pd.DataFrame(allWordsDf['clean1'].apply(clean_text_round2))
allWordsDf
# Out:
#          word  count    clean1    clean2
# 0         ...     93
# 1    delivery     55  delivery  delivery
# 2         bad     45       bad       bad
# 3         day     33       day       day
# 4        item     29      item      item
# ..        ...    ...       ...       ...
# 515      need      1      need      need
# 516    picked      1    picked    picked
# 517   running      1   running   running
# 518   hearing      1   hearing   hearing
# 519    buzzer      1    buzzer    buzzer
#
# [520 rows x 4 columns]

# %%
allWordsDf['Sentiment'] = pd.DataFrame(allWordsDf['clean2'].apply(sentiment_scores))

# %%
allWordsDf
# Out:
#          word  count    clean1    clean2 Sentiment
# 0         ...     93                       Neutral
# 1    delivery     55  delivery  delivery   Neutral
# 2         bad     45       bad       bad  Negative
# 3         day     33       day       day   Neutral
# 4        item     29      item      item   Neutral
# ..        ...    ...       ...       ...       ...
# 515      need      1      need      need   Neutral
# 516    picked      1    picked    picked   Neutral
# 517   running      1   running   running   Neutral
# 518   hearing      1   hearing   hearing   Neutral
# 519    buzzer      1    buzzer    buzzer   Neutral
#
# [520 rows x 5 columns]

# %%
pd.DataFrame(allWordsDf).to_csv('Ninja_th_words_counter_sentiment.csv', encoding='utf8')

# %%
#add meaningless words to stopwords
add_stop_words = ['...' , 'package', 'even', 'use','call','one','though', 'didnt', 'dont', 'hasnt', 'c',]
stop_words = add_stop_words + stop

# %%
#wordcloud for top 100 words 
wc = WordCloud(stopwords=stop_words, background_color="white", colormap="Dark2",
               max_font_size=150, random_state=42, max_words = 100)

wordcloud = wc.generate(cloud_string)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
plt.figure( figsize=(20,10) )
plt.imshow(wordcloud)

# %%
late_words = ['slow', 'late', 'long']
df_late = df_neg[df_neg['Reviews_processed2'].str.contains('|'.join(late_words))]
df_late = df_late.rename(columns ={'Reviews_processed2':'Late reviews'})

# %%
column_titles = ['rating','Reviews','Sentiment']
df_late = df_late.reindex(columns=column_titles)
df_late
# Out:
#      rating                                            Reviews Sentiment
# 18      2.0   Order online from the shop and deliver with t...  Negative
# 20      1.0   Waiting for the parcel for a long time, the s...  Negative
# 33      1.0   Sucks. Slow delivery. Pickled items. No deliv...  Negative
# 36      1.0   Pickled items are very good, don't send items...  Negative
# 45      1.0   Too bad, too long, ineffective irresponsible ...  Negative
# 48      1.0       Very slow delivery, it will be ruined soon    Negative
# 50      1.0   Very slow, send it, don't call Items can't be...  Negative
# 58      1.0   Very bad service, ordering a lot of things, c...  Negative
# 63      1.0   Very slow delivery, said that I pressed the w...  Negative
# 67      1.0     Slow delivery, wait until you're discouraged    Negative
# 81      1.0   Worst As far as I can tell you straight It's ...  Negative
# 101     1.0   I don't want to give a star at all. Delivery ...  Negative
# 112     1.0   This transport, the worst service, the worst,...  Negative
# 119     1.0   Very slow Not recommended, can be avoided, sh...  Negative
# 122     1.0   The delivery of this company is very slow, ho...  Negative
# 125     1.0   Ordered with se-ed, pay, express delivery, bu...  Negative
# 140     1.0   It is a bad transport, slow delivery, employe...  Negative
# 143     1.0   The system is terrible. Products sent 4 days ...  Negative
# 151     1.0   The transportation system is very low. Never ...  Negative
# 156     1.0   Very bad, very late delivery Added to the fal...  Negative
# 168     1.0   Terrible, very slow transportation, the deliv...  Negative
# 241     5.0   Responsible employees are the very essence of...  Negative
# 391     4.0   After the shop in Shoppi reported that he had...  Negative
# 401     5.0   Monday's order Wednesday afternoon, three rec...  Negative
# 459     1.0   The delivery was very slow and the item retur...  Negative
# 471     2.0   Slow delivery. Take your convenience. Postpon...  Negative

# %%
df_late.to_csv('Late_reviews_ninjath.csv')
